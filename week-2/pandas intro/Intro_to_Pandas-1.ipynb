# %% [markdown]
# # Numpy and Pandas
#
# ## Objectives:
#
# - Use numpy.random to generate a dataset.
# - Read in various forms of data into a panadas dataframe
# - Perform some basic operations on the dataframe

# %% [markdown]
# ## Agenda
#
# - Review Numpy
# - Introduce Pandas
# - Reading in data and merging dataframes (DF)
# - working with missing values
# - Slicing, selecing and xxtracting data

# %% [markdown]
# ## Numpy

# %% [markdown]
# - There is nothing in NumPy which can’t be done via python lists or by using other data structures.
# - NumPy provides an efficient storage and better way handling of the data for mathematical operations using simple API’s.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %%
# Create an array of 25 numbers between -1 and 1
pure = np.linspace(-1, 1, 25)

# %%
pure
# Out:
# array([-1.        , -0.91666667, -0.83333333, -0.75      , -0.66666667,
#        -0.58333333, -0.5       , -0.41666667, -0.33333333, -0.25      ,
#        -0.16666667, -0.08333333,  0.        ,  0.08333333,  0.16666667,
#         0.25      ,  0.33333333,  0.41666667,  0.5       ,  0.58333333,
#         0.66666667,  0.75      ,  0.83333333,  0.91666667,  1.        ])

# %%
# Create a scatterplot where the x and y both refer to the array created above
plt.plot(pure, pure, 'o', color='black');

# %%
#Add some noise to the data by randomly generating numbers between 0 and .5 to add to the Ys
noise = np.random.normal(0, .5, pure.shape, )
signal = pure + noise
plt.plot(pure, signal, 'o', color='black');

# %%
# Graph a log transformation of the numbers
np.random.seed(1234)
pure = np.linspace(0, 10000, 50)
noise = np.random.normal(-.2, .2, pure.shape)
y = np.log(pure)
signal = y + noise
# Out:
# /Users/gabrielseemann/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in log
#   """

# %%
# Create plot
fig, ax = plt.subplots()
ax.scatter(pure, signal)
ax.set_title('Log Transformation scatter plot')

plt.show()

# %% [markdown]
# **Use a numpy function to transform the `pure` data series and then create your own scatterplot of the new data with the `pure` data.**

# %%
# Create plot
fig, ax = plt.subplots()

#transform your data with a numpy function
y2 = np.cos(pure)

#plot the newly retransformed graph
ax.scatter(pure, y2)

#rename your grpah
ax.set_title('exp trans')

plt.show()

# %% [markdown]
# ## Pandas

# %%
import pandas as pd

# %% [markdown]
# ### Core components of pandas: Series and DataFrames
#
# The primary two components of pandas are the `Series` and `DataFrame`.
#
# A Series is essentially a column, and a DataFrame is a multi-dimensional table made up of a collection of Series.

# %% [markdown]
# <img src="series-and-dataframe.png" alt="drawing" width="600"/>

# %%
# help(pd.DataFrame)

# %% [markdown]
# ## Creating a Dataframe
#
# A dataframe can be created from many different types of data sources.  Below are diffeten examples of this.

# %% [markdown]
# ### Create from dictionaries

# %% [markdown]
# ### Create a dataframe from a csv file

# %%
movies = pd.read_csv('IMDB-Movie-Data.csv')
movies.head(1)
# Out:
#    Rank                    Title                    Genre  \
# 0     1  Guardians of the Galaxy  Action,Adventure,Sci-Fi
#
#                                          Description    Director  \
# 0  A group of intergalactic criminals are forced ...  James Gunn
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
#
#    Rating   Votes  Revenue (Millions)  Metascore
# 0     8.1  757074              333.13       76.0

# %% [markdown]
# ### Read CSV from weburl
#
# *If you are doing this from git, make sure you have the url for the raw csv file*

# %%
pd.read_csv('https://raw.githubusercontent.com/learn-co-students/nyc-mhtn-ds-071519-lectures/master/week-1/Descriptive_Statistics/weight-height.csv')
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# 5       Male  67.253016  152.212156
# 6       Male  68.785081  183.927889
# 7       Male  68.348516  167.971110
# 8       Male  67.018950  175.929440
# 9       Male  63.456494  156.399676
# 10      Male  71.195382  186.604926
# 11      Male  71.640805  213.741169
# 12      Male  64.766329  167.127461
# 13      Male  69.283070  189.446181
# 14      Male  69.243732  186.434168
# 15      Male  67.645620  172.186930
# 16      Male  72.418317  196.028506
# 17      Male  63.974326  172.883470
# 18      Male  69.640060  185.983958
# 19      Male  67.936005  182.426648
# 20      Male  67.915050  174.115929
# 21      Male  69.439440  197.731422
# 22      Male  66.149132  149.173566
# 23      Male  75.205974  228.761781
# 24      Male  67.893196  162.006652
# 25      Male  68.144033  192.343977
# 26      Male  69.089631  184.435174
# 27      Male  72.800844  206.828189
# 28      Male  67.421242  175.213922
# 29      Male  68.496415  154.342639
# ...      ...        ...         ...
# 9970  Female  65.618737  151.500389
# 9971  Female  64.640247  155.318297
# 9972  Female  60.653733  123.084293
# 9973  Female  60.737031  120.926500
# 9974  Female  65.393947  143.017835
# 9975  Female  66.251923  124.019917
# 9976  Female  61.475904  121.387236
# 9977  Female  64.494838  149.402547
# 9978  Female  57.375759  114.192209
# 9979  Female  62.056012  125.135897
# 9980  Female  60.472262  110.768229
# 9981  Female  60.443264  135.559390
# 9982  Female  69.868511  177.992066
# 9983  Female  65.830726  132.827889
# 9984  Female  59.047029  111.707369
# 9985  Female  68.041065  170.514213
# 9986  Female  63.352698  141.906510
# 9987  Female  65.610243  151.169475
# 9988  Female  59.538729  121.244876
# 9989  Female  60.955084   95.686674
# 9990  Female  63.179498  141.266100
# 9991  Female  62.636675  102.853563
# 9992  Female  62.077832  138.691680
# 9993  Female  60.030434   97.687432
# 9994  Female  59.098250  110.529686
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %% [markdown]
# ### Read in excel file

# %% [markdown]
# There is a file called `1617FedSchoolCodeList.xlsx` in this directory.Look up how to read an excel file into a dataframe and do it.

# %%
pd.read_excel('1617FedSchoolCodeList.xlsx', index_col='ID')   #separator ='\t'can be used
# Out:
#       SchoolCode                                SchoolName  \
# ID
# 25969     B04724           WIDENER UNIV SCHOOL OF LAW - DE
# 25970     B06171       CENTER FOR ADVANCED STUDIES OF PUER
# 25971     B06511          PENTECOSTAL THEOLOGICAL SEMINARY
# 25972     B07022     THE CHICAGO SCHOOL OF PROF PSYCHOLOGY
# 25973     B07624      NATIONAL COLLEGE OF NATURAL MEDICINE
# 25974     B07625           OREGON COL OF ORIENTAL MEDICINE
# 25975     B08041              ALFRED ADLER GRADUATE SCHOOL
# 25976     B08083   UNIV OF THE DIST OF COLU -SCHOOL OF LAW
# 25977     B42154                  GRACE SCHOOL OF THEOLOGY
# 25978     E00014        AMRCN REPERTORY THTR INST ADV THTR
# 25979     E00058        BROWN UNIVERSITY - GRADUATE SCHOOL
# 25980     E00059                      BROWN MEDICAL SCHOOL
# 25981     E00073   CARNEGIE MELLON UNIV- THE HEINZ COLLEGE
# 25982     E00074  CARNEGIE MELLON- TEPPER SCHOOL OF BUSINE
# 25983     E00077            CASE WESTERN RESERVE UNIV - UG
# 25984     E00078        CASE WESTERN RESERVE UNIV - DENTAL
# 25985     E00079           CASE WESTERN RESERVE UNIV - MED
# 25986     E00080          CASE WESTERN RESERVE UNIV - WSOM
# 25987     E00081       CASE WESTERN RESERVE UNIV - NURS UG
# 25988     E00082           CASE WESTERN RESERVE UNIV - LAW
# 25989     E00083       CASE WESTERN RESERVE UNIV -NURS GRD
# 25990     E00084         CASE WESTERN RESERVE UNIV - MSASS
# 25991     E00131         CATHOLIC UNIV AMERICA, LAW SCHOOL
# 25992     E00170                EARLHAM SCHOOL OF RELIGION
# 25993     E00171      EAST TENNESSEE STATE UNIV - MEDICINE
# 25994     E00177              ERSKINE THEOLOGICAL SEMINARY
# 25995     E00196           GEORGE WASHINGTON UNIV LAW SCHL
# 25996     E00197            GEORGE WASHINGTON UNIV SCH MED
# 25997     E00209                  HARVARD EXTENSION SCHOOL
# 25998     E00210                   HARVARD DIVINITY SCHOOL
# ...          ...                                       ...
# 32901     042520            YESHIVA GEDOLAH SHAAREI SHMUEL
# 32902     042336                        MED-LIFE INSTITUTE
# 32903     042450                NORTHWEST SUBURBAN COLLEGE
# 32904     042466         TEXTURES INSTITUTE OF COSMETOLOGY
# 32905     042523                  PREMIER BARBER INSTITUTE
# 32906     E40424                 UEI COLLEGE - BAKERSFIELD
# 32907     042562              KENNY'S ACADEMY OF BARBERING
# 32908     042514          ELIM BIBLE INSTITUTE AND COLLEGE
# 32909     042428                   CAAN ACADEMY OF NURSING
# 32910     042556            INTERNATIONAL DIVING INSTITUTE
# 32911     G21544         BEAU MONDE COLLEGE OF HAIR DESIGN
# 32912     042561  INDIANA COLLEGE OF SPORTS & MEDICAL MASS
# 32913     042555  ALABAMA SCHOOL OF NAIL TECHNOLOGY & COSM
# 32914     042531           ALLIED HEALTH CAREERS INSTITUTE
# 32915     E40425                    FLORIDA CAREER COLLEGE
# 32916     E40426  FLORIDA CAREER COLLEGE - WEST PALM BEACH
# 32917     E40427           FLORIDA CAREER COLLEGE -HIALEAH
# 32918     E40428  FLORIDA CAREER COLLEGE - LAUDERDALE LAKE
# 32919     E40429           FLORIDA CAREER COLLEGE -  TAMPA
# 32920     E40430     FLORIDA CAREER COLLEGE - JACKSONVILLE
# 32921     E40431    FLORIDA CAREER COLLEGE - BOYNTON BEACH
# 32922     E40432          FLORIDA CAREER COLLEGE - MARGATE
# 32923     E40433          FLORIDA CAREER COLLEGE - KENDALL
# 32924     E40434          FLORIDA CAREER COLLEGE - ORLANDO
# 32925     E40435  FLORIDA CAREER COLLEGE - UEI COLLEGE - P
# 32926     E40436  FLORIDA CAREER COLLEGE - UEI COLLEGE - H
# 32927     042496                      WESTCLIFF UNIVERSITY
# 32928     042534                  CLOVIS COMMUNITY COLLEGE
# 32929     042577  TOTALLY COSMO SCHOOL OF MODERN COSMETOLO
# 32930     042488     WONGU UNIVERSITY OF ORIENTAL MEDICINE
#
#                                    Address              City StateCode  \
# ID
# 25969        4601 CONCORD PIKE/PO BOX 7474        WILMINGTON        DE
# 25970                           BOX S-4467          SAN JUAN        PR
# 25971                          PO BOX 3330         CLEVELAND        TN
# 25972               325 NORTH WELLS STREET           CHICAGO        IL
# 25973                        049 SW PORTER          PORTLAND        OR
# 25974           10525 SE CHERRY BLOSSOM DR          PORTLAND        OR
# 25975       1001 WEST HIGHWAY 7  SUITE 344           HOPKINS        MN
# 25976           4200 CONNECTICUT AVENUE NW        WASHINGTON        DC
# 25977                 3705 COLLEGE PARK DR            CONROE        TX
# 25978                    64 BRATTLE STREET         CAMBRIDGE        MA
# 25979                        8 FONES ALLEY        PROVIDENCE        RI
# 25980       97 WATERMAN STREET  BOX G-A212        PROVIDENCE        RI
# 25981                   5000 FORBES AVENUE        PITTSBURGH        PA
# 25982                   5000 FORBES AVENUE        PITTSBURGH        PA
# 25983                  10900 EUCLID AVENUE         CLEVELAND        OH
# 25984                     10900 EUCLID AVE         CLEVELAND        OH
# 25985               10900 EUCLID AVE T-303         CLEVELAND        OH
# 25986                     10900 EUCLID AVE         CLEVELAND        OH
# 25987                     10900 EUCLID AVE         CLEVELAND        OH
# 25988                     10900 EUCLID AVE         CLEVELAND        OH
# 25989                     10900 EUCLID AVE         CLEVELAND        OH
# 25990                     10900 EUCLID AVE         CLEVELAND        OH
# 25991       OFC FNCL AID  CARDINAL STATION        WASHINGTON        DC
# 25992                   228 COLLEGE AVENUE          RICHMOND        IN
# 25993               VA CAMPUS MAPLE AVENUE      JOHNSON CITY        TN
# 25994                           PO BOX 668          DUE WEST        SC
# 25995                     2000 H STREET NW        WASHINGTON        DC
# 25996                         2300 I ST NW        WASHINGTON        DC
# 25997                    51 BRATTLE STREET         CAMBRIDGE        MA
# 25998                      14 DIVINITY AVE         CAMBRIDGE        MA
# ...                                    ...               ...       ...
# 32901                     511 OCEAN AVENUE          LAKEWOOD        NJ
# 32902                 4000 N. STATE ROAD 7  LAUDERDALE LAKES        FL
# 32903               5999 S. NEW WILKE ROAD    ROLLNG MEADOWS        IL
# 32904             8325 NORTH MICHIGAN ROAD      INDIANAPOLIS        IN
# 32905                 573 EAST MAIN STREET        NORRISTOWN        PA
# 32906                3737 ROSEDALE HIGHWAY       BAKERSFIELD        CA
# 32907                  2150 LAFAYETTE ROAD      INDIANAPOLIS        IN
# 32908                  7245 COLLEGE STREET              LIMA        NY
# 32909    4747 LINCOLN MALL DR. - SUITE 420          MATTESON        IL
# 32910                 1400 PIERSIDE STREET  NORTH CHARLESTON        SC
# 32911                  1221 SW 12TH AVENUE          PORTLAND        OR
# 32912                184 WEST CARMEL DRIVE            CARMEL        IN
# 32913                  202 COMMERCE STREET           JACKSON        AL
# 32914      1800 SOUTH RUTHERFORD BOULEVARD      MURFREESBORO        TN
# 32915                 7891 PINES BOULEVARD    PEMBROKE PINES        FL
# 32916                6058 OKEECHOBEE BLVD.   WEST PALM BEACH        FL
# 32917                  3750 WEST 18 AVENUE           HIALEAH        FL
# 32918              3383 NORTH STATE ROAD 7  LAUDERDALE LAKES        FL
# 32919  9950 PRINCESS PALM AVENUE SUITE 100             TAMPA        FL
# 32920               6600 YOUNGERMAN CIRCLE      JACKSONVILLE        FL
# 32921           1749 NORTH CONGRESS AVENUE     BOYNTON BEACH        FL
# 32922                 3271 N. STATE ROAD 7           MARGATE        FL
# 32923                    11731 MILLS DRIVE             MIAMI        FL
# 32924          989 NORTH SEMORAN BOULEVARD           ORLANDO        FL
# 32925         9215 N. BLACK CANYON HIGHWAY           PHOENIX        AZ
# 32926   70-A FARM TO MARKET ROAD 1960 WEST           HOUSTON        TX
# 32927               4199 CAMPUS DRIVE #650            IRVINE        CA
# 32928            10309 NORTH WILLOW AVENUE            FRESNO        CA
# 32929                   110 NORTH BROADWAY        BROKEN BOW        OK
# 32930            8620 SOUTH EASTERN AVENUE         LAS VEGAS        NV
#
#        ZipCode Province Country PostalCode
# ID
# 25969    19803      NaN     NaN        NaN
# 25970      902      NaN     NaN        NaN
# 25971    37320      NaN     NaN        NaN
# 25972    60610      NaN     NaN        NaN
# 25973    97201      NaN     NaN        NaN
# 25974    97216      NaN     NaN        NaN
# 25975    55305      NaN     NaN        NaN
# 25976    20008      NaN     NaN        NaN
# 25977    77384      NaN     NaN        NaN
# 25978     2138      NaN     NaN        NaN
# 25979     2912      NaN     NaN        NaN
# 25980     2912      NaN     NaN        NaN
# 25981    15213      NaN     NaN        NaN
# 25982    15213      NaN     NaN        NaN
# 25983    44106      NaN     NaN        NaN
# 25984    44106      NaN     NaN        NaN
# 25985    44106      NaN     NaN        NaN
# 25986    44106      NaN     NaN        NaN
# 25987    44106      NaN     NaN        NaN
# 25988    44106      NaN     NaN        NaN
# 25989    44106      NaN     NaN        NaN
# 25990    44106      NaN     NaN        NaN
# 25991    20064      NaN     NaN        NaN
# 25992    47374      NaN     NaN        NaN
# 25993    37614      NaN     NaN        NaN
# 25994    29639      NaN     NaN        NaN
# 25995    20052      NaN     NaN        NaN
# 25996    20052      NaN     NaN        NaN
# 25997     2138      NaN     NaN        NaN
# 25998     2138      NaN     NaN        NaN
# ...        ...      ...     ...        ...
# 32901     8701      NaN     NaN        NaN
# 32902    33319      NaN     NaN        NaN
# 32903    60008      NaN     NaN        NaN
# 32904    46268      NaN     NaN        NaN
# 32905    19401      NaN     NaN        NaN
# 32906    93308      NaN     NaN        NaN
# 32907    46222      NaN     NaN        NaN
# 32908    14485      NaN     NaN        NaN
# 32909    60443      NaN     NaN        NaN
# 32910    29405      NaN     NaN        NaN
# 32911    97205      NaN     NaN        NaN
# 32912    46032      NaN     NaN        NaN
# 32913    36545      NaN     NaN        NaN
# 32914    37130      NaN     NaN        NaN
# 32915    33024      NaN     NaN        NaN
# 32916    33417      NaN     NaN        NaN
# 32917    33012      NaN     NaN        NaN
# 32918    33319      NaN     NaN        NaN
# 32919    33619      NaN     NaN        NaN
# 32920    32244      NaN     NaN        NaN
# 32921    33426      NaN     NaN        NaN
# 32922    33063      NaN     NaN        NaN
# 32923    33183      NaN     NaN        NaN
# 32924    32807      NaN     NaN        NaN
# 32925    85021      NaN     NaN        NaN
# 32926    77090      NaN     NaN        NaN
# 32927    92612      NaN     NaN        NaN
# 32928    93730      NaN     NaN        NaN
# 32929    74728      NaN     NaN        NaN
# 32930    89123      NaN     NaN        NaN
#
# [6962 rows x 9 columns]

# %% [markdown]
# ### Create from  from json

# %%
import json
db = json.load(open('foods-2011-10-03.json'))
len(db)
# Out:
# 6636

# %%
db2 = pd.read_json('foods-2011-10-03.json')      #also works

# %%
db2
# Out:
#                                             description  \
# 0                                       Cheese, caraway
# 1                                       Cheese, cheddar
# 2                                          Cheese, edam
# 3                                          Cheese, feta
# 4                    Cheese, mozzarella, part skim milk
# 5      Cheese, mozzarella, part skim milk, low moisture
# 6                                        Cheese, romano
# 7                                     Cheese, roquefort
# 8     Cheese spread, pasteurized process, american, ...
# 9                           Cream, fluid, half and half
# 10    Sour dressing, non-butterfat, cultured, filled...
# 11    Milk, filled, fluid, with blend of hydrogenate...
# 12    Cream substitute, liquid, with lauric acid oil...
# 13                           Cream substitute, powdered
# 14                  Milk, producer, fluid, 3.7% milkfat
# 15    Milk, reduced fat, fluid, 2% milkfat, with add...
# 16    Milk, reduced fat, fluid, 2% milkfat, with add...
# 17    Milk, reduced fat, fluid, 2% milkfat, protein ...
# 18    Milk, lowfat, fluid, 1% milkfat, with added vi...
# 19    Milk, lowfat, fluid, 1% milkfat, with added no...
# 20    Milk, lowfat, fluid, 1% milkfat, protein forti...
# 21    Milk, nonfat, fluid, with added vitamin A and ...
# 22    Milk, nonfat, fluid, with added nonfat milk so...
# 23    Milk, nonfat, fluid, protein fortified, with a...
# 24            Milk, buttermilk, fluid, cultured, lowfat
# 25                              Milk, low sodium, fluid
# 26               Milk, dry, whole, with added vitamin D
# 27    Milk, dry, nonfat, regular, without added vita...
# 28    Milk, dry, nonfat, instant, with added vitamin...
# 29                   Milk, dry, nonfat, calcium reduced
# ...                                                 ...
# 6606  Beef, tenderloin, steak, separable lean only, ...
# 6607  Beef, top sirloin, steak, separable lean only,...
# 6608  Beef, short loin, top loin, steak, separable l...
# 6609  Beef, chuck, arm pot roast, separable lean onl...
# 6610  Beef, brisket, flat half, separable lean only,...
# 6611  Beef, chuck, arm pot roast, separable lean onl...
# 6612  Beef, brisket, flat half, separable lean only,...
# 6613  Beef, round, eye of round, roast, separable le...
# 6614  Beef, round, top round, steak, separable lean ...
# 6615  Beef, round, bottom round, roast, separable le...
# 6616  Beef, rib, small end (ribs 10-12), separable l...
# 6617  CAMPBELL Soup Company, CAMPBELL'S Red and Whit...
# 6618  CAMPBELL Soup Company, CAMPBELL's Red and Whit...
# 6619  CAMPBELL Soup Company, CAMPBELL'S SELECT Soups...
# 6620  CAMPBELL Soup Company, CAMPBELL'S SOUP AT HAND...
# 6621  CAMPBELL Soup Company, CAMPBELL'S SOUP AT HAND...
# 6622  CAMPBELL Soup Company, CAMPBELL'S SELECT Gold ...
# 6623  CAMPBELL Soup Company, CAMPBELL'S SELECT Gold ...
# 6624  CAMPBELL Soup Company, CAMPBELL'S SELECT Gold ...
# 6625  CAMPBELL Soup Company, CAMPBELL'S Red and Whit...
# 6626  CAMPBELL Soup Company, V8 Vegetable Juice, Ess...
# 6627  CAMPBELL Soup Company, V8 Vegetable Juice, Spi...
# 6628  CAMPBELL Soup Company, PACE, Jalapenos Nacho S...
# 6629  CAMPBELL Soup Company, V8 60% Vegetable Juice,...
# 6630  CAMPBELL Soup Company, V8 Vegetable Juice, Low...
# 6631                             Bologna, beef, low fat
# 6632  Turkey and pork sausage, fresh, bulk, patty or...
# 6633                              Babyfood, juice, pear
# 6634         Babyfood, dessert, banana yogurt, strained
# 6635              Babyfood, banana no tapioca, strained
#
#                                   group     id       manufacturer  \
# 0                Dairy and Egg Products   1008
# 1                Dairy and Egg Products   1009
# 2                Dairy and Egg Products   1018
# 3                Dairy and Egg Products   1019
# 4                Dairy and Egg Products   1028
# 5                Dairy and Egg Products   1029
# 6                Dairy and Egg Products   1038
# 7                Dairy and Egg Products   1039
# 8                Dairy and Egg Products   1048
# 9                Dairy and Egg Products   1049
# 10               Dairy and Egg Products   1058
# 11               Dairy and Egg Products   1059
# 12               Dairy and Egg Products   1068
# 13               Dairy and Egg Products   1069
# 14               Dairy and Egg Products   1078
# 15               Dairy and Egg Products   1079               None
# 16               Dairy and Egg Products   1080
# 17               Dairy and Egg Products   1081
# 18               Dairy and Egg Products   1082
# 19               Dairy and Egg Products   1083
# 20               Dairy and Egg Products   1084
# 21               Dairy and Egg Products   1085
# 22               Dairy and Egg Products   1086
# 23               Dairy and Egg Products   1087
# 24               Dairy and Egg Products   1088
# 25               Dairy and Egg Products   1089
# 26               Dairy and Egg Products   1090
# 27               Dairy and Egg Products   1091
# 28               Dairy and Egg Products   1092
# 29               Dairy and Egg Products   1093
# ...                                 ...    ...                ...
# 6606                      Beef Products  23628
# 6607                      Beef Products  23629
# 6608                      Beef Products  23630
# 6609                      Beef Products  23631
# 6610                      Beef Products  23632
# 6611                      Beef Products  23633
# 6612                      Beef Products  23634
# 6613                      Beef Products  23635
# 6614                      Beef Products  23636
# 6615                      Beef Products  23637
# 6616                      Beef Products  23638
# 6617         Soups, Sauces, and Gravies  27015  Campbell Soup Co.
# 6618         Soups, Sauces, and Gravies  27016  Campbell Soup Co.
# 6619         Soups, Sauces, and Gravies  27021  Campbell Soup Co.
# 6620         Soups, Sauces, and Gravies  27022  Campbell Soup Co.
# 6621         Soups, Sauces, and Gravies  27023  Campbell Soup Co.
# 6622         Soups, Sauces, and Gravies  27024  Campbell Soup Co.
# 6623         Soups, Sauces, and Gravies  27025  Campbell Soup Co.
# 6624         Soups, Sauces, and Gravies  27026  Campbell Soup Co.
# 6625         Soups, Sauces, and Gravies  27032  Campbell Soup Co.
# 6626  Vegetables and Vegetable Products  31010  Campbell Soup Co.
# 6627  Vegetables and Vegetable Products  31013  Campbell Soup Co.
# 6628  Vegetables and Vegetable Products  31014  Campbell Soup Co.
# 6629  Vegetables and Vegetable Products  31016  Campbell Soup Co.
# 6630  Vegetables and Vegetable Products  31017  Campbell Soup Co.
# 6631        Sausages and Luncheon Meats  42161
# 6632        Sausages and Luncheon Meats  42173
# 6633                         Baby Foods  43408               None
# 6634                         Baby Foods  43539               None
# 6635                         Baby Foods  43546               None
#
#                                               nutrients  \
# 0     [{'value': 25.18, 'units': 'g', 'description':...
# 1     [{'value': 24.9, 'units': 'g', 'description': ...
# 2     [{'value': 4.22, 'units': 'g', 'description': ...
# 3     [{'value': 5.2, 'units': 'g', 'description': '...
# 4     [{'value': 3.27, 'units': 'g', 'description': ...
# 5     [{'value': 3.7199999999999998, 'units': 'g', '...
# 6     [{'value': 31.8, 'units': 'g', 'description': ...
# 7     [{'value': 21.54, 'units': 'g', 'description':...
# 8     [{'value': 16.41, 'units': 'g', 'description':...
# 9     [{'value': 2.96, 'units': 'g', 'description': ...
# 10    [{'value': 3.25, 'units': 'g', 'description': ...
# 11    [{'value': 3.33, 'units': 'g', 'description': ...
# 12    [{'value': 1.0, 'units': 'g', 'description': '...
# 13    [{'value': 4.79, 'units': 'g', 'description': ...
# 14    [{'value': 3.2800000000000002, 'units': 'g', '...
# 15    [{'value': 3.3, 'units': 'g', 'description': '...
# 16    [{'value': 3.48, 'units': 'g', 'description': ...
# 17    [{'value': 3.95, 'units': 'g', 'description': ...
# 18    [{'value': 3.37, 'units': 'g', 'description': ...
# 19    [{'value': 3.48, 'units': 'g', 'description': ...
# 20    [{'value': 3.93, 'units': 'g', 'description': ...
# 21    [{'value': 3.37, 'units': 'g', 'description': ...
# 22    [{'value': 3.5700000000000003, 'units': 'g', '...
# 23    [{'value': 3.96, 'units': 'g', 'description': ...
# 24    [{'value': 3.31, 'units': 'g', 'description': ...
# 25    [{'value': 3.1, 'units': 'g', 'description': '...
# 26    [{'value': 26.32, 'units': 'g', 'description':...
# 27    [{'value': 36.16, 'units': 'g', 'description':...
# 28    [{'value': 35.1, 'units': 'g', 'description': ...
# 29    [{'value': 35.5, 'units': 'g', 'description': ...
# ...                                                 ...
# 6606  [{'value': 29.01, 'units': 'g', 'description':...
# 6607  [{'value': 29.51, 'units': 'g', 'description':...
# 6608  [{'value': 29.16, 'units': 'g', 'description':...
# 6609  [{'value': 22.26, 'units': 'g', 'description':...
# 6610  [{'value': 21.45, 'units': 'g', 'description':...
# 6611  [{'value': 34.6, 'units': 'g', 'description': ...
# 6612  [{'value': 33.18, 'units': 'g', 'description':...
# 6613  [{'value': 22.31, 'units': 'g', 'description':...
# 6614  [{'value': 23.13, 'units': 'g', 'description':...
# 6615  [{'value': 22.18, 'units': 'g', 'description':...
# 6616  [{'value': 29.58, 'units': 'g', 'description':...
# 6617  [{'value': 2.38, 'units': 'g', 'description': ...
# 6618  [{'value': 3.17, 'units': 'g', 'description': ...
# 6619  [{'value': 2.86, 'units': 'g', 'description': ...
# 6620  [{'value': 1.31, 'units': 'g', 'description': ...
# 6621  [{'value': 0.98, 'units': 'g', 'description': ...
# 6622  [{'value': 2.04, 'units': 'g', 'description': ...
# 6623  [{'value': 1.22, 'units': 'g', 'description': ...
# 6624  [{'value': 1.22, 'units': 'g', 'description': ...
# 6625  [{'value': 6.35, 'units': 'g', 'description': ...
# 6626  [{'value': 0.8200000000000001, 'units': 'g', '...
# 6627  [{'value': 0.8200000000000001, 'units': 'g', '...
# 6628  [{'value': 0.0, 'units': 'g', 'description': '...
# 6629  [{'value': 0.41000000000000003, 'units': 'g', ...
# 6630  [{'value': 0.8200000000000001, 'units': 'g', '...
# 6631  [{'value': 11.8, 'units': 'g', 'description': ...
# 6632  [{'value': 22.7, 'units': 'g', 'description': ...
# 6633  [{'value': 0.0, 'units': 'g', 'description': '...
# 6634  [{'value': 1.1, 'units': 'g', 'description': '...
# 6635  [{'value': 1.0, 'units': 'g', 'description': '...
#
#                                                portions            tags
# 0         [{'amount': 1, 'unit': 'oz', 'grams': 28.35}]              []
# 1     [{'amount': 1, 'unit': 'cup, diced', 'grams': ...              []
# 2     [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...              []
# 3     [{'amount': 1, 'unit': 'cup, crumbled', 'grams...              []
# 4         [{'amount': 1, 'unit': 'oz', 'grams': 28.35}]              []
# 5     [{'amount': 1, 'unit': 'cup, diced', 'grams': ...              []
# 6     [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...              []
# 7     [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...              []
# 8     [{'amount': 1, 'unit': 'cup, diced', 'grams': ...              []
# 9     [{'amount': 1, 'unit': 'cup', 'grams': 242.0},...              []
# 10    [{'amount': 1, 'unit': 'cup', 'grams': 235.0},...              []
# 11    [{'amount': 1, 'unit': 'cup', 'grams': 244.0},...              []
# 12    [{'amount': 1, 'unit': 'container, individual'...              []
# 13    [{'amount': 1, 'unit': 'cup', 'grams': 94.0}, ...              []
# 14    [{'amount': 1, 'unit': 'cup', 'grams': 244.0},...              []
# 15    [{'amount': 1, 'unit': 'cup', 'grams': 244.0},...              []
# 16    [{'amount': 1, 'unit': 'cup', 'grams': 245.0},...              []
# 17    [{'amount': 1, 'unit': 'cup', 'grams': 246.0},...              []
# 18    [{'amount': 1, 'unit': 'cup', 'grams': 244.0},...              []
# 19    [{'amount': 1, 'unit': 'cup', 'grams': 245.0},...              []
# 20    [{'amount': 1, 'unit': 'cup', 'grams': 246.0},...              []
# 21    [{'amount': 1, 'unit': 'cup', 'grams': 245.0},...              []
# 22    [{'amount': 1, 'unit': 'cup', 'grams': 245.0},...              []
# 23    [{'amount': 1, 'unit': 'cup', 'grams': 246.0},...              []
# 24    [{'amount': 1, 'unit': 'cup', 'grams': 245.0},...              []
# 25    [{'amount': 1, 'unit': 'cup', 'grams': 244.0},...              []
# 26    [{'amount': 1, 'unit': 'cup', 'grams': 128.0},...              []
# 27    [{'amount': 1, 'unit': 'cup', 'grams': 120.0},...              []
# 28    [{'amount': 1, 'unit': 'cup', 'grams': 68.0}, ...              []
# 29    [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...              []
# ...                                                 ...             ...
# 6606  [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...   [URMIS #2203]
# 6607  [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...   [URMIS #2237]
# 6608  [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...  [URMIS # 2213]
# 6609  [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...   [URMIS #1049]
# 6610  [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...   [URMIS #1623]
# 6611  [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...   [URMIS #1049]
# 6612  [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...   [URMIS #1623]
# 6613  [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...   [URMIS #1480]
# 6614  [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...   [URMIS #1553]
# 6615  [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...   [URMIS #1464]
# 6616  [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...              []
# 6617  [{'amount': 1, 'unit': 'cup', 'grams': 126.0},...              []
# 6618  [{'amount': 1, 'unit': 'cup', 'grams': 126.0},...              []
# 6619  [{'amount': 1, 'unit': 'cup', 'grams': 245.0},...              []
# 6620  [{'amount': 1, 'unit': 'serving', 'grams': 305...              []
# 6621  [{'amount': 1, 'unit': 'serving', 'grams': 305...              []
# 6622  [{'amount': 1, 'unit': 'cup', 'grams': 245.0},...              []
# 6623  [{'amount': 1, 'unit': 'cup', 'grams': 245.0},...              []
# 6624  [{'amount': 1, 'unit': 'cup', 'grams': 245.0},...              []
# 6625  [{'amount': 1, 'unit': 'cup', 'grams': 126.0},...              []
# 6626  [{'amount': 1, 'unit': 'oz', 'grams': 243.0}, ...              []
# 6627  [{'amount': 1, 'unit': 'fl oz', 'grams': 243.0...              []
# 6628  [{'amount': 1, 'unit': 'oz', 'grams': 30.0}, {...              []
# 6629  [{'amount': 1, 'unit': 'fl oz', 'grams': 243.0...              []
# 6630  [{'amount': 1, 'unit': 'fl oz', 'grams': 243.0...              []
# 6631  [{'amount': 1, 'unit': 'slice', 'grams': 28.0}...              []
# 6632  [{'amount': 1, 'unit': 'cup, cooked', 'grams':...              []
# 6633  [{'amount': 1, 'unit': 'fl oz', 'grams': 31.2}...              []
# 6634  [{'amount': 1, 'unit': 'tbsp', 'grams': 15.0},...              []
# 6635  [{'amount': 1, 'unit': 'tbsp', 'grams': 15.0},...              []
#
# [6636 rows x 7 columns]

# %%
pd.DataFrame(db)
# Out:
#                                             description  \
# 0                                       Cheese, caraway
# 1                                       Cheese, cheddar
# 2                                          Cheese, edam
# 3                                          Cheese, feta
# 4                    Cheese, mozzarella, part skim milk
# 5      Cheese, mozzarella, part skim milk, low moisture
# 6                                        Cheese, romano
# 7                                     Cheese, roquefort
# 8     Cheese spread, pasteurized process, american, ...
# 9                           Cream, fluid, half and half
# 10    Sour dressing, non-butterfat, cultured, filled...
# 11    Milk, filled, fluid, with blend of hydrogenate...
# 12    Cream substitute, liquid, with lauric acid oil...
# 13                           Cream substitute, powdered
# 14                  Milk, producer, fluid, 3.7% milkfat
# 15    Milk, reduced fat, fluid, 2% milkfat, with add...
# 16    Milk, reduced fat, fluid, 2% milkfat, with add...
# 17    Milk, reduced fat, fluid, 2% milkfat, protein ...
# 18    Milk, lowfat, fluid, 1% milkfat, with added vi...
# 19    Milk, lowfat, fluid, 1% milkfat, with added no...
# 20    Milk, lowfat, fluid, 1% milkfat, protein forti...
# 21    Milk, nonfat, fluid, with added vitamin A and ...
# 22    Milk, nonfat, fluid, with added nonfat milk so...
# 23    Milk, nonfat, fluid, protein fortified, with a...
# 24            Milk, buttermilk, fluid, cultured, lowfat
# 25                              Milk, low sodium, fluid
# 26               Milk, dry, whole, with added vitamin D
# 27    Milk, dry, nonfat, regular, without added vita...
# 28    Milk, dry, nonfat, instant, with added vitamin...
# 29                   Milk, dry, nonfat, calcium reduced
# ...                                                 ...
# 6606  Beef, tenderloin, steak, separable lean only, ...
# 6607  Beef, top sirloin, steak, separable lean only,...
# 6608  Beef, short loin, top loin, steak, separable l...
# 6609  Beef, chuck, arm pot roast, separable lean onl...
# 6610  Beef, brisket, flat half, separable lean only,...
# 6611  Beef, chuck, arm pot roast, separable lean onl...
# 6612  Beef, brisket, flat half, separable lean only,...
# 6613  Beef, round, eye of round, roast, separable le...
# 6614  Beef, round, top round, steak, separable lean ...
# 6615  Beef, round, bottom round, roast, separable le...
# 6616  Beef, rib, small end (ribs 10-12), separable l...
# 6617  CAMPBELL Soup Company, CAMPBELL'S Red and Whit...
# 6618  CAMPBELL Soup Company, CAMPBELL's Red and Whit...
# 6619  CAMPBELL Soup Company, CAMPBELL'S SELECT Soups...
# 6620  CAMPBELL Soup Company, CAMPBELL'S SOUP AT HAND...
# 6621  CAMPBELL Soup Company, CAMPBELL'S SOUP AT HAND...
# 6622  CAMPBELL Soup Company, CAMPBELL'S SELECT Gold ...
# 6623  CAMPBELL Soup Company, CAMPBELL'S SELECT Gold ...
# 6624  CAMPBELL Soup Company, CAMPBELL'S SELECT Gold ...
# 6625  CAMPBELL Soup Company, CAMPBELL'S Red and Whit...
# 6626  CAMPBELL Soup Company, V8 Vegetable Juice, Ess...
# 6627  CAMPBELL Soup Company, V8 Vegetable Juice, Spi...
# 6628  CAMPBELL Soup Company, PACE, Jalapenos Nacho S...
# 6629  CAMPBELL Soup Company, V8 60% Vegetable Juice,...
# 6630  CAMPBELL Soup Company, V8 Vegetable Juice, Low...
# 6631                             Bologna, beef, low fat
# 6632  Turkey and pork sausage, fresh, bulk, patty or...
# 6633                              Babyfood, juice, pear
# 6634         Babyfood, dessert, banana yogurt, strained
# 6635              Babyfood, banana no tapioca, strained
#
#                                   group     id       manufacturer  \
# 0                Dairy and Egg Products   1008
# 1                Dairy and Egg Products   1009
# 2                Dairy and Egg Products   1018
# 3                Dairy and Egg Products   1019
# 4                Dairy and Egg Products   1028
# 5                Dairy and Egg Products   1029
# 6                Dairy and Egg Products   1038
# 7                Dairy and Egg Products   1039
# 8                Dairy and Egg Products   1048
# 9                Dairy and Egg Products   1049
# 10               Dairy and Egg Products   1058
# 11               Dairy and Egg Products   1059
# 12               Dairy and Egg Products   1068
# 13               Dairy and Egg Products   1069
# 14               Dairy and Egg Products   1078
# 15               Dairy and Egg Products   1079               None
# 16               Dairy and Egg Products   1080
# 17               Dairy and Egg Products   1081
# 18               Dairy and Egg Products   1082
# 19               Dairy and Egg Products   1083
# 20               Dairy and Egg Products   1084
# 21               Dairy and Egg Products   1085
# 22               Dairy and Egg Products   1086
# 23               Dairy and Egg Products   1087
# 24               Dairy and Egg Products   1088
# 25               Dairy and Egg Products   1089
# 26               Dairy and Egg Products   1090
# 27               Dairy and Egg Products   1091
# 28               Dairy and Egg Products   1092
# 29               Dairy and Egg Products   1093
# ...                                 ...    ...                ...
# 6606                      Beef Products  23628
# 6607                      Beef Products  23629
# 6608                      Beef Products  23630
# 6609                      Beef Products  23631
# 6610                      Beef Products  23632
# 6611                      Beef Products  23633
# 6612                      Beef Products  23634
# 6613                      Beef Products  23635
# 6614                      Beef Products  23636
# 6615                      Beef Products  23637
# 6616                      Beef Products  23638
# 6617         Soups, Sauces, and Gravies  27015  Campbell Soup Co.
# 6618         Soups, Sauces, and Gravies  27016  Campbell Soup Co.
# 6619         Soups, Sauces, and Gravies  27021  Campbell Soup Co.
# 6620         Soups, Sauces, and Gravies  27022  Campbell Soup Co.
# 6621         Soups, Sauces, and Gravies  27023  Campbell Soup Co.
# 6622         Soups, Sauces, and Gravies  27024  Campbell Soup Co.
# 6623         Soups, Sauces, and Gravies  27025  Campbell Soup Co.
# 6624         Soups, Sauces, and Gravies  27026  Campbell Soup Co.
# 6625         Soups, Sauces, and Gravies  27032  Campbell Soup Co.
# 6626  Vegetables and Vegetable Products  31010  Campbell Soup Co.
# 6627  Vegetables and Vegetable Products  31013  Campbell Soup Co.
# 6628  Vegetables and Vegetable Products  31014  Campbell Soup Co.
# 6629  Vegetables and Vegetable Products  31016  Campbell Soup Co.
# 6630  Vegetables and Vegetable Products  31017  Campbell Soup Co.
# 6631        Sausages and Luncheon Meats  42161
# 6632        Sausages and Luncheon Meats  42173
# 6633                         Baby Foods  43408               None
# 6634                         Baby Foods  43539               None
# 6635                         Baby Foods  43546               None
#
#                                               nutrients  \
# 0     [{'value': 25.18, 'units': 'g', 'description':...
# 1     [{'value': 24.9, 'units': 'g', 'description': ...
# 2     [{'value': 4.22, 'units': 'g', 'description': ...
# 3     [{'value': 5.2, 'units': 'g', 'description': '...
# 4     [{'value': 3.27, 'units': 'g', 'description': ...
# 5     [{'value': 3.72, 'units': 'g', 'description': ...
# 6     [{'value': 31.8, 'units': 'g', 'description': ...
# 7     [{'value': 21.54, 'units': 'g', 'description':...
# 8     [{'value': 16.41, 'units': 'g', 'description':...
# 9     [{'value': 2.96, 'units': 'g', 'description': ...
# 10    [{'value': 3.25, 'units': 'g', 'description': ...
# 11    [{'value': 3.33, 'units': 'g', 'description': ...
# 12    [{'value': 1.0, 'units': 'g', 'description': '...
# 13    [{'value': 4.79, 'units': 'g', 'description': ...
# 14    [{'value': 3.28, 'units': 'g', 'description': ...
# 15    [{'value': 3.3, 'units': 'g', 'description': '...
# 16    [{'value': 3.48, 'units': 'g', 'description': ...
# 17    [{'value': 3.95, 'units': 'g', 'description': ...
# 18    [{'value': 3.37, 'units': 'g', 'description': ...
# 19    [{'value': 3.48, 'units': 'g', 'description': ...
# 20    [{'value': 3.93, 'units': 'g', 'description': ...
# 21    [{'value': 3.37, 'units': 'g', 'description': ...
# 22    [{'value': 3.57, 'units': 'g', 'description': ...
# 23    [{'value': 3.96, 'units': 'g', 'description': ...
# 24    [{'value': 3.31, 'units': 'g', 'description': ...
# 25    [{'value': 3.1, 'units': 'g', 'description': '...
# 26    [{'value': 26.32, 'units': 'g', 'description':...
# 27    [{'value': 36.16, 'units': 'g', 'description':...
# 28    [{'value': 35.1, 'units': 'g', 'description': ...
# 29    [{'value': 35.5, 'units': 'g', 'description': ...
# ...                                                 ...
# 6606  [{'value': 29.01, 'units': 'g', 'description':...
# 6607  [{'value': 29.51, 'units': 'g', 'description':...
# 6608  [{'value': 29.16, 'units': 'g', 'description':...
# 6609  [{'value': 22.26, 'units': 'g', 'description':...
# 6610  [{'value': 21.45, 'units': 'g', 'description':...
# 6611  [{'value': 34.6, 'units': 'g', 'description': ...
# 6612  [{'value': 33.18, 'units': 'g', 'description':...
# 6613  [{'value': 22.31, 'units': 'g', 'description':...
# 6614  [{'value': 23.13, 'units': 'g', 'description':...
# 6615  [{'value': 22.18, 'units': 'g', 'description':...
# 6616  [{'value': 29.58, 'units': 'g', 'description':...
# 6617  [{'value': 2.38, 'units': 'g', 'description': ...
# 6618  [{'value': 3.17, 'units': 'g', 'description': ...
# 6619  [{'value': 2.86, 'units': 'g', 'description': ...
# 6620  [{'value': 1.31, 'units': 'g', 'description': ...
# 6621  [{'value': 0.98, 'units': 'g', 'description': ...
# 6622  [{'value': 2.04, 'units': 'g', 'description': ...
# 6623  [{'value': 1.22, 'units': 'g', 'description': ...
# 6624  [{'value': 1.22, 'units': 'g', 'description': ...
# 6625  [{'value': 6.35, 'units': 'g', 'description': ...
# 6626  [{'value': 0.82, 'units': 'g', 'description': ...
# 6627  [{'value': 0.82, 'units': 'g', 'description': ...
# 6628  [{'value': 0.0, 'units': 'g', 'description': '...
# 6629  [{'value': 0.41, 'units': 'g', 'description': ...
# 6630  [{'value': 0.82, 'units': 'g', 'description': ...
# 6631  [{'value': 11.8, 'units': 'g', 'description': ...
# 6632  [{'value': 22.7, 'units': 'g', 'description': ...
# 6633  [{'value': 0.0, 'units': 'g', 'description': '...
# 6634  [{'value': 1.1, 'units': 'g', 'description': '...
# 6635  [{'value': 1.0, 'units': 'g', 'description': '...
#
#                                                portions            tags
# 0         [{'amount': 1, 'unit': 'oz', 'grams': 28.35}]              []
# 1     [{'amount': 1, 'unit': 'cup, diced', 'grams': ...              []
# 2     [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...              []
# 3     [{'amount': 1, 'unit': 'cup, crumbled', 'grams...              []
# 4         [{'amount': 1, 'unit': 'oz', 'grams': 28.35}]              []
# 5     [{'amount': 1, 'unit': 'cup, diced', 'grams': ...              []
# 6     [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...              []
# 7     [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...              []
# 8     [{'amount': 1, 'unit': 'cup, diced', 'grams': ...              []
# 9     [{'amount': 1, 'unit': 'cup', 'grams': 242.0},...              []
# 10    [{'amount': 1, 'unit': 'cup', 'grams': 235.0},...              []
# 11    [{'amount': 1, 'unit': 'cup', 'grams': 244.0},...              []
# 12    [{'amount': 1, 'unit': 'container, individual'...              []
# 13    [{'amount': 1, 'unit': 'cup', 'grams': 94.0}, ...              []
# 14    [{'amount': 1, 'unit': 'cup', 'grams': 244.0},...              []
# 15    [{'amount': 1, 'unit': 'cup', 'grams': 244.0},...              []
# 16    [{'amount': 1, 'unit': 'cup', 'grams': 245.0},...              []
# 17    [{'amount': 1, 'unit': 'cup', 'grams': 246.0},...              []
# 18    [{'amount': 1, 'unit': 'cup', 'grams': 244.0},...              []
# 19    [{'amount': 1, 'unit': 'cup', 'grams': 245.0},...              []
# 20    [{'amount': 1, 'unit': 'cup', 'grams': 246.0},...              []
# 21    [{'amount': 1, 'unit': 'cup', 'grams': 245.0},...              []
# 22    [{'amount': 1, 'unit': 'cup', 'grams': 245.0},...              []
# 23    [{'amount': 1, 'unit': 'cup', 'grams': 246.0},...              []
# 24    [{'amount': 1, 'unit': 'cup', 'grams': 245.0},...              []
# 25    [{'amount': 1, 'unit': 'cup', 'grams': 244.0},...              []
# 26    [{'amount': 1, 'unit': 'cup', 'grams': 128.0},...              []
# 27    [{'amount': 1, 'unit': 'cup', 'grams': 120.0},...              []
# 28    [{'amount': 1, 'unit': 'cup', 'grams': 68.0}, ...              []
# 29    [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...              []
# ...                                                 ...             ...
# 6606  [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...   [URMIS #2203]
# 6607  [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...   [URMIS #2237]
# 6608  [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...  [URMIS # 2213]
# 6609  [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...   [URMIS #1049]
# 6610  [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...   [URMIS #1623]
# 6611  [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...   [URMIS #1049]
# 6612  [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...   [URMIS #1623]
# 6613  [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...   [URMIS #1480]
# 6614  [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...   [URMIS #1553]
# 6615  [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...   [URMIS #1464]
# 6616  [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...              []
# 6617  [{'amount': 1, 'unit': 'cup', 'grams': 126.0},...              []
# 6618  [{'amount': 1, 'unit': 'cup', 'grams': 126.0},...              []
# 6619  [{'amount': 1, 'unit': 'cup', 'grams': 245.0},...              []
# 6620  [{'amount': 1, 'unit': 'serving', 'grams': 305...              []
# 6621  [{'amount': 1, 'unit': 'serving', 'grams': 305...              []
# 6622  [{'amount': 1, 'unit': 'cup', 'grams': 245.0},...              []
# 6623  [{'amount': 1, 'unit': 'cup', 'grams': 245.0},...              []
# 6624  [{'amount': 1, 'unit': 'cup', 'grams': 245.0},...              []
# 6625  [{'amount': 1, 'unit': 'cup', 'grams': 126.0},...              []
# 6626  [{'amount': 1, 'unit': 'oz', 'grams': 243.0}, ...              []
# 6627  [{'amount': 1, 'unit': 'fl oz', 'grams': 243.0...              []
# 6628  [{'amount': 1, 'unit': 'oz', 'grams': 30.0}, {...              []
# 6629  [{'amount': 1, 'unit': 'fl oz', 'grams': 243.0...              []
# 6630  [{'amount': 1, 'unit': 'fl oz', 'grams': 243.0...              []
# 6631  [{'amount': 1, 'unit': 'slice', 'grams': 28.0}...              []
# 6632  [{'amount': 1, 'unit': 'cup, cooked', 'grams':...              []
# 6633  [{'amount': 1, 'unit': 'fl oz', 'grams': 31.2}...              []
# 6634  [{'amount': 1, 'unit': 'tbsp', 'grams': 15.0},...              []
# 6635  [{'amount': 1, 'unit': 'tbsp', 'grams': 15.0},...              []
#
# [6636 rows x 7 columns]

# %%
pd.read_json('foods-2011-10-03.json')
# Out:
#                                             description  \
# 0                                       Cheese, caraway
# 1                                       Cheese, cheddar
# 2                                          Cheese, edam
# 3                                          Cheese, feta
# 4                    Cheese, mozzarella, part skim milk
# 5      Cheese, mozzarella, part skim milk, low moisture
# 6                                        Cheese, romano
# 7                                     Cheese, roquefort
# 8     Cheese spread, pasteurized process, american, ...
# 9                           Cream, fluid, half and half
# 10    Sour dressing, non-butterfat, cultured, filled...
# 11    Milk, filled, fluid, with blend of hydrogenate...
# 12    Cream substitute, liquid, with lauric acid oil...
# 13                           Cream substitute, powdered
# 14                  Milk, producer, fluid, 3.7% milkfat
# 15    Milk, reduced fat, fluid, 2% milkfat, with add...
# 16    Milk, reduced fat, fluid, 2% milkfat, with add...
# 17    Milk, reduced fat, fluid, 2% milkfat, protein ...
# 18    Milk, lowfat, fluid, 1% milkfat, with added vi...
# 19    Milk, lowfat, fluid, 1% milkfat, with added no...
# 20    Milk, lowfat, fluid, 1% milkfat, protein forti...
# 21    Milk, nonfat, fluid, with added vitamin A and ...
# 22    Milk, nonfat, fluid, with added nonfat milk so...
# 23    Milk, nonfat, fluid, protein fortified, with a...
# 24            Milk, buttermilk, fluid, cultured, lowfat
# 25                              Milk, low sodium, fluid
# 26               Milk, dry, whole, with added vitamin D
# 27    Milk, dry, nonfat, regular, without added vita...
# 28    Milk, dry, nonfat, instant, with added vitamin...
# 29                   Milk, dry, nonfat, calcium reduced
# ...                                                 ...
# 6606  Beef, tenderloin, steak, separable lean only, ...
# 6607  Beef, top sirloin, steak, separable lean only,...
# 6608  Beef, short loin, top loin, steak, separable l...
# 6609  Beef, chuck, arm pot roast, separable lean onl...
# 6610  Beef, brisket, flat half, separable lean only,...
# 6611  Beef, chuck, arm pot roast, separable lean onl...
# 6612  Beef, brisket, flat half, separable lean only,...
# 6613  Beef, round, eye of round, roast, separable le...
# 6614  Beef, round, top round, steak, separable lean ...
# 6615  Beef, round, bottom round, roast, separable le...
# 6616  Beef, rib, small end (ribs 10-12), separable l...
# 6617  CAMPBELL Soup Company, CAMPBELL'S Red and Whit...
# 6618  CAMPBELL Soup Company, CAMPBELL's Red and Whit...
# 6619  CAMPBELL Soup Company, CAMPBELL'S SELECT Soups...
# 6620  CAMPBELL Soup Company, CAMPBELL'S SOUP AT HAND...
# 6621  CAMPBELL Soup Company, CAMPBELL'S SOUP AT HAND...
# 6622  CAMPBELL Soup Company, CAMPBELL'S SELECT Gold ...
# 6623  CAMPBELL Soup Company, CAMPBELL'S SELECT Gold ...
# 6624  CAMPBELL Soup Company, CAMPBELL'S SELECT Gold ...
# 6625  CAMPBELL Soup Company, CAMPBELL'S Red and Whit...
# 6626  CAMPBELL Soup Company, V8 Vegetable Juice, Ess...
# 6627  CAMPBELL Soup Company, V8 Vegetable Juice, Spi...
# 6628  CAMPBELL Soup Company, PACE, Jalapenos Nacho S...
# 6629  CAMPBELL Soup Company, V8 60% Vegetable Juice,...
# 6630  CAMPBELL Soup Company, V8 Vegetable Juice, Low...
# 6631                             Bologna, beef, low fat
# 6632  Turkey and pork sausage, fresh, bulk, patty or...
# 6633                              Babyfood, juice, pear
# 6634         Babyfood, dessert, banana yogurt, strained
# 6635              Babyfood, banana no tapioca, strained
#
#                                   group     id       manufacturer  \
# 0                Dairy and Egg Products   1008
# 1                Dairy and Egg Products   1009
# 2                Dairy and Egg Products   1018
# 3                Dairy and Egg Products   1019
# 4                Dairy and Egg Products   1028
# 5                Dairy and Egg Products   1029
# 6                Dairy and Egg Products   1038
# 7                Dairy and Egg Products   1039
# 8                Dairy and Egg Products   1048
# 9                Dairy and Egg Products   1049
# 10               Dairy and Egg Products   1058
# 11               Dairy and Egg Products   1059
# 12               Dairy and Egg Products   1068
# 13               Dairy and Egg Products   1069
# 14               Dairy and Egg Products   1078
# 15               Dairy and Egg Products   1079               None
# 16               Dairy and Egg Products   1080
# 17               Dairy and Egg Products   1081
# 18               Dairy and Egg Products   1082
# 19               Dairy and Egg Products   1083
# 20               Dairy and Egg Products   1084
# 21               Dairy and Egg Products   1085
# 22               Dairy and Egg Products   1086
# 23               Dairy and Egg Products   1087
# 24               Dairy and Egg Products   1088
# 25               Dairy and Egg Products   1089
# 26               Dairy and Egg Products   1090
# 27               Dairy and Egg Products   1091
# 28               Dairy and Egg Products   1092
# 29               Dairy and Egg Products   1093
# ...                                 ...    ...                ...
# 6606                      Beef Products  23628
# 6607                      Beef Products  23629
# 6608                      Beef Products  23630
# 6609                      Beef Products  23631
# 6610                      Beef Products  23632
# 6611                      Beef Products  23633
# 6612                      Beef Products  23634
# 6613                      Beef Products  23635
# 6614                      Beef Products  23636
# 6615                      Beef Products  23637
# 6616                      Beef Products  23638
# 6617         Soups, Sauces, and Gravies  27015  Campbell Soup Co.
# 6618         Soups, Sauces, and Gravies  27016  Campbell Soup Co.
# 6619         Soups, Sauces, and Gravies  27021  Campbell Soup Co.
# 6620         Soups, Sauces, and Gravies  27022  Campbell Soup Co.
# 6621         Soups, Sauces, and Gravies  27023  Campbell Soup Co.
# 6622         Soups, Sauces, and Gravies  27024  Campbell Soup Co.
# 6623         Soups, Sauces, and Gravies  27025  Campbell Soup Co.
# 6624         Soups, Sauces, and Gravies  27026  Campbell Soup Co.
# 6625         Soups, Sauces, and Gravies  27032  Campbell Soup Co.
# 6626  Vegetables and Vegetable Products  31010  Campbell Soup Co.
# 6627  Vegetables and Vegetable Products  31013  Campbell Soup Co.
# 6628  Vegetables and Vegetable Products  31014  Campbell Soup Co.
# 6629  Vegetables and Vegetable Products  31016  Campbell Soup Co.
# 6630  Vegetables and Vegetable Products  31017  Campbell Soup Co.
# 6631        Sausages and Luncheon Meats  42161
# 6632        Sausages and Luncheon Meats  42173
# 6633                         Baby Foods  43408               None
# 6634                         Baby Foods  43539               None
# 6635                         Baby Foods  43546               None
#
#                                               nutrients  \
# 0     [{'value': 25.18, 'units': 'g', 'description':...
# 1     [{'value': 24.9, 'units': 'g', 'description': ...
# 2     [{'value': 4.22, 'units': 'g', 'description': ...
# 3     [{'value': 5.2, 'units': 'g', 'description': '...
# 4     [{'value': 3.27, 'units': 'g', 'description': ...
# 5     [{'value': 3.7199999999999998, 'units': 'g', '...
# 6     [{'value': 31.8, 'units': 'g', 'description': ...
# 7     [{'value': 21.54, 'units': 'g', 'description':...
# 8     [{'value': 16.41, 'units': 'g', 'description':...
# 9     [{'value': 2.96, 'units': 'g', 'description': ...
# 10    [{'value': 3.25, 'units': 'g', 'description': ...
# 11    [{'value': 3.33, 'units': 'g', 'description': ...
# 12    [{'value': 1.0, 'units': 'g', 'description': '...
# 13    [{'value': 4.79, 'units': 'g', 'description': ...
# 14    [{'value': 3.2800000000000002, 'units': 'g', '...
# 15    [{'value': 3.3, 'units': 'g', 'description': '...
# 16    [{'value': 3.48, 'units': 'g', 'description': ...
# 17    [{'value': 3.95, 'units': 'g', 'description': ...
# 18    [{'value': 3.37, 'units': 'g', 'description': ...
# 19    [{'value': 3.48, 'units': 'g', 'description': ...
# 20    [{'value': 3.93, 'units': 'g', 'description': ...
# 21    [{'value': 3.37, 'units': 'g', 'description': ...
# 22    [{'value': 3.5700000000000003, 'units': 'g', '...
# 23    [{'value': 3.96, 'units': 'g', 'description': ...
# 24    [{'value': 3.31, 'units': 'g', 'description': ...
# 25    [{'value': 3.1, 'units': 'g', 'description': '...
# 26    [{'value': 26.32, 'units': 'g', 'description':...
# 27    [{'value': 36.16, 'units': 'g', 'description':...
# 28    [{'value': 35.1, 'units': 'g', 'description': ...
# 29    [{'value': 35.5, 'units': 'g', 'description': ...
# ...                                                 ...
# 6606  [{'value': 29.01, 'units': 'g', 'description':...
# 6607  [{'value': 29.51, 'units': 'g', 'description':...
# 6608  [{'value': 29.16, 'units': 'g', 'description':...
# 6609  [{'value': 22.26, 'units': 'g', 'description':...
# 6610  [{'value': 21.45, 'units': 'g', 'description':...
# 6611  [{'value': 34.6, 'units': 'g', 'description': ...
# 6612  [{'value': 33.18, 'units': 'g', 'description':...
# 6613  [{'value': 22.31, 'units': 'g', 'description':...
# 6614  [{'value': 23.13, 'units': 'g', 'description':...
# 6615  [{'value': 22.18, 'units': 'g', 'description':...
# 6616  [{'value': 29.58, 'units': 'g', 'description':...
# 6617  [{'value': 2.38, 'units': 'g', 'description': ...
# 6618  [{'value': 3.17, 'units': 'g', 'description': ...
# 6619  [{'value': 2.86, 'units': 'g', 'description': ...
# 6620  [{'value': 1.31, 'units': 'g', 'description': ...
# 6621  [{'value': 0.98, 'units': 'g', 'description': ...
# 6622  [{'value': 2.04, 'units': 'g', 'description': ...
# 6623  [{'value': 1.22, 'units': 'g', 'description': ...
# 6624  [{'value': 1.22, 'units': 'g', 'description': ...
# 6625  [{'value': 6.35, 'units': 'g', 'description': ...
# 6626  [{'value': 0.8200000000000001, 'units': 'g', '...
# 6627  [{'value': 0.8200000000000001, 'units': 'g', '...
# 6628  [{'value': 0.0, 'units': 'g', 'description': '...
# 6629  [{'value': 0.41000000000000003, 'units': 'g', ...
# 6630  [{'value': 0.8200000000000001, 'units': 'g', '...
# 6631  [{'value': 11.8, 'units': 'g', 'description': ...
# 6632  [{'value': 22.7, 'units': 'g', 'description': ...
# 6633  [{'value': 0.0, 'units': 'g', 'description': '...
# 6634  [{'value': 1.1, 'units': 'g', 'description': '...
# 6635  [{'value': 1.0, 'units': 'g', 'description': '...
#
#                                                portions            tags
# 0         [{'amount': 1, 'unit': 'oz', 'grams': 28.35}]              []
# 1     [{'amount': 1, 'unit': 'cup, diced', 'grams': ...              []
# 2     [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...              []
# 3     [{'amount': 1, 'unit': 'cup, crumbled', 'grams...              []
# 4         [{'amount': 1, 'unit': 'oz', 'grams': 28.35}]              []
# 5     [{'amount': 1, 'unit': 'cup, diced', 'grams': ...              []
# 6     [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...              []
# 7     [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...              []
# 8     [{'amount': 1, 'unit': 'cup, diced', 'grams': ...              []
# 9     [{'amount': 1, 'unit': 'cup', 'grams': 242.0},...              []
# 10    [{'amount': 1, 'unit': 'cup', 'grams': 235.0},...              []
# 11    [{'amount': 1, 'unit': 'cup', 'grams': 244.0},...              []
# 12    [{'amount': 1, 'unit': 'container, individual'...              []
# 13    [{'amount': 1, 'unit': 'cup', 'grams': 94.0}, ...              []
# 14    [{'amount': 1, 'unit': 'cup', 'grams': 244.0},...              []
# 15    [{'amount': 1, 'unit': 'cup', 'grams': 244.0},...              []
# 16    [{'amount': 1, 'unit': 'cup', 'grams': 245.0},...              []
# 17    [{'amount': 1, 'unit': 'cup', 'grams': 246.0},...              []
# 18    [{'amount': 1, 'unit': 'cup', 'grams': 244.0},...              []
# 19    [{'amount': 1, 'unit': 'cup', 'grams': 245.0},...              []
# 20    [{'amount': 1, 'unit': 'cup', 'grams': 246.0},...              []
# 21    [{'amount': 1, 'unit': 'cup', 'grams': 245.0},...              []
# 22    [{'amount': 1, 'unit': 'cup', 'grams': 245.0},...              []
# 23    [{'amount': 1, 'unit': 'cup', 'grams': 246.0},...              []
# 24    [{'amount': 1, 'unit': 'cup', 'grams': 245.0},...              []
# 25    [{'amount': 1, 'unit': 'cup', 'grams': 244.0},...              []
# 26    [{'amount': 1, 'unit': 'cup', 'grams': 128.0},...              []
# 27    [{'amount': 1, 'unit': 'cup', 'grams': 120.0},...              []
# 28    [{'amount': 1, 'unit': 'cup', 'grams': 68.0}, ...              []
# 29    [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...              []
# ...                                                 ...             ...
# 6606  [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...   [URMIS #2203]
# 6607  [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...   [URMIS #2237]
# 6608  [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...  [URMIS # 2213]
# 6609  [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...   [URMIS #1049]
# 6610  [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...   [URMIS #1623]
# 6611  [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...   [URMIS #1049]
# 6612  [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...   [URMIS #1623]
# 6613  [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...   [URMIS #1480]
# 6614  [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...   [URMIS #1553]
# 6615  [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...   [URMIS #1464]
# 6616  [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...              []
# 6617  [{'amount': 1, 'unit': 'cup', 'grams': 126.0},...              []
# 6618  [{'amount': 1, 'unit': 'cup', 'grams': 126.0},...              []
# 6619  [{'amount': 1, 'unit': 'cup', 'grams': 245.0},...              []
# 6620  [{'amount': 1, 'unit': 'serving', 'grams': 305...              []
# 6621  [{'amount': 1, 'unit': 'serving', 'grams': 305...              []
# 6622  [{'amount': 1, 'unit': 'cup', 'grams': 245.0},...              []
# 6623  [{'amount': 1, 'unit': 'cup', 'grams': 245.0},...              []
# 6624  [{'amount': 1, 'unit': 'cup', 'grams': 245.0},...              []
# 6625  [{'amount': 1, 'unit': 'cup', 'grams': 126.0},...              []
# 6626  [{'amount': 1, 'unit': 'oz', 'grams': 243.0}, ...              []
# 6627  [{'amount': 1, 'unit': 'fl oz', 'grams': 243.0...              []
# 6628  [{'amount': 1, 'unit': 'oz', 'grams': 30.0}, {...              []
# 6629  [{'amount': 1, 'unit': 'fl oz', 'grams': 243.0...              []
# 6630  [{'amount': 1, 'unit': 'fl oz', 'grams': 243.0...              []
# 6631  [{'amount': 1, 'unit': 'slice', 'grams': 28.0}...              []
# 6632  [{'amount': 1, 'unit': 'cup, cooked', 'grams':...              []
# 6633  [{'amount': 1, 'unit': 'fl oz', 'grams': 31.2}...              []
# 6634  [{'amount': 1, 'unit': 'tbsp', 'grams': 15.0},...              []
# 6635  [{'amount': 1, 'unit': 'tbsp', 'grams': 15.0},...              []
#
# [6636 rows x 7 columns]

# %%
info_keys = ['description', 'group', 'id', 'manufacturer']
info = pd.DataFrame(db, columns=info_keys)
info
# Out:
#                                             description  \
# 0                                       Cheese, caraway
# 1                                       Cheese, cheddar
# 2                                          Cheese, edam
# 3                                          Cheese, feta
# 4                    Cheese, mozzarella, part skim milk
# 5      Cheese, mozzarella, part skim milk, low moisture
# 6                                        Cheese, romano
# 7                                     Cheese, roquefort
# 8     Cheese spread, pasteurized process, american, ...
# 9                           Cream, fluid, half and half
# 10    Sour dressing, non-butterfat, cultured, filled...
# 11    Milk, filled, fluid, with blend of hydrogenate...
# 12    Cream substitute, liquid, with lauric acid oil...
# 13                           Cream substitute, powdered
# 14                  Milk, producer, fluid, 3.7% milkfat
# 15    Milk, reduced fat, fluid, 2% milkfat, with add...
# 16    Milk, reduced fat, fluid, 2% milkfat, with add...
# 17    Milk, reduced fat, fluid, 2% milkfat, protein ...
# 18    Milk, lowfat, fluid, 1% milkfat, with added vi...
# 19    Milk, lowfat, fluid, 1% milkfat, with added no...
# 20    Milk, lowfat, fluid, 1% milkfat, protein forti...
# 21    Milk, nonfat, fluid, with added vitamin A and ...
# 22    Milk, nonfat, fluid, with added nonfat milk so...
# 23    Milk, nonfat, fluid, protein fortified, with a...
# 24            Milk, buttermilk, fluid, cultured, lowfat
# 25                              Milk, low sodium, fluid
# 26               Milk, dry, whole, with added vitamin D
# 27    Milk, dry, nonfat, regular, without added vita...
# 28    Milk, dry, nonfat, instant, with added vitamin...
# 29                   Milk, dry, nonfat, calcium reduced
# ...                                                 ...
# 6606  Beef, tenderloin, steak, separable lean only, ...
# 6607  Beef, top sirloin, steak, separable lean only,...
# 6608  Beef, short loin, top loin, steak, separable l...
# 6609  Beef, chuck, arm pot roast, separable lean onl...
# 6610  Beef, brisket, flat half, separable lean only,...
# 6611  Beef, chuck, arm pot roast, separable lean onl...
# 6612  Beef, brisket, flat half, separable lean only,...
# 6613  Beef, round, eye of round, roast, separable le...
# 6614  Beef, round, top round, steak, separable lean ...
# 6615  Beef, round, bottom round, roast, separable le...
# 6616  Beef, rib, small end (ribs 10-12), separable l...
# 6617  CAMPBELL Soup Company, CAMPBELL'S Red and Whit...
# 6618  CAMPBELL Soup Company, CAMPBELL's Red and Whit...
# 6619  CAMPBELL Soup Company, CAMPBELL'S SELECT Soups...
# 6620  CAMPBELL Soup Company, CAMPBELL'S SOUP AT HAND...
# 6621  CAMPBELL Soup Company, CAMPBELL'S SOUP AT HAND...
# 6622  CAMPBELL Soup Company, CAMPBELL'S SELECT Gold ...
# 6623  CAMPBELL Soup Company, CAMPBELL'S SELECT Gold ...
# 6624  CAMPBELL Soup Company, CAMPBELL'S SELECT Gold ...
# 6625  CAMPBELL Soup Company, CAMPBELL'S Red and Whit...
# 6626  CAMPBELL Soup Company, V8 Vegetable Juice, Ess...
# 6627  CAMPBELL Soup Company, V8 Vegetable Juice, Spi...
# 6628  CAMPBELL Soup Company, PACE, Jalapenos Nacho S...
# 6629  CAMPBELL Soup Company, V8 60% Vegetable Juice,...
# 6630  CAMPBELL Soup Company, V8 Vegetable Juice, Low...
# 6631                             Bologna, beef, low fat
# 6632  Turkey and pork sausage, fresh, bulk, patty or...
# 6633                              Babyfood, juice, pear
# 6634         Babyfood, dessert, banana yogurt, strained
# 6635              Babyfood, banana no tapioca, strained
#
#                                   group     id       manufacturer
# 0                Dairy and Egg Products   1008
# 1                Dairy and Egg Products   1009
# 2                Dairy and Egg Products   1018
# 3                Dairy and Egg Products   1019
# 4                Dairy and Egg Products   1028
# 5                Dairy and Egg Products   1029
# 6                Dairy and Egg Products   1038
# 7                Dairy and Egg Products   1039
# 8                Dairy and Egg Products   1048
# 9                Dairy and Egg Products   1049
# 10               Dairy and Egg Products   1058
# 11               Dairy and Egg Products   1059
# 12               Dairy and Egg Products   1068
# 13               Dairy and Egg Products   1069
# 14               Dairy and Egg Products   1078
# 15               Dairy and Egg Products   1079               None
# 16               Dairy and Egg Products   1080
# 17               Dairy and Egg Products   1081
# 18               Dairy and Egg Products   1082
# 19               Dairy and Egg Products   1083
# 20               Dairy and Egg Products   1084
# 21               Dairy and Egg Products   1085
# 22               Dairy and Egg Products   1086
# 23               Dairy and Egg Products   1087
# 24               Dairy and Egg Products   1088
# 25               Dairy and Egg Products   1089
# 26               Dairy and Egg Products   1090
# 27               Dairy and Egg Products   1091
# 28               Dairy and Egg Products   1092
# 29               Dairy and Egg Products   1093
# ...                                 ...    ...                ...
# 6606                      Beef Products  23628
# 6607                      Beef Products  23629
# 6608                      Beef Products  23630
# 6609                      Beef Products  23631
# 6610                      Beef Products  23632
# 6611                      Beef Products  23633
# 6612                      Beef Products  23634
# 6613                      Beef Products  23635
# 6614                      Beef Products  23636
# 6615                      Beef Products  23637
# 6616                      Beef Products  23638
# 6617         Soups, Sauces, and Gravies  27015  Campbell Soup Co.
# 6618         Soups, Sauces, and Gravies  27016  Campbell Soup Co.
# 6619         Soups, Sauces, and Gravies  27021  Campbell Soup Co.
# 6620         Soups, Sauces, and Gravies  27022  Campbell Soup Co.
# 6621         Soups, Sauces, and Gravies  27023  Campbell Soup Co.
# 6622         Soups, Sauces, and Gravies  27024  Campbell Soup Co.
# 6623         Soups, Sauces, and Gravies  27025  Campbell Soup Co.
# 6624         Soups, Sauces, and Gravies  27026  Campbell Soup Co.
# 6625         Soups, Sauces, and Gravies  27032  Campbell Soup Co.
# 6626  Vegetables and Vegetable Products  31010  Campbell Soup Co.
# 6627  Vegetables and Vegetable Products  31013  Campbell Soup Co.
# 6628  Vegetables and Vegetable Products  31014  Campbell Soup Co.
# 6629  Vegetables and Vegetable Products  31016  Campbell Soup Co.
# 6630  Vegetables and Vegetable Products  31017  Campbell Soup Co.
# 6631        Sausages and Luncheon Meats  42161
# 6632        Sausages and Luncheon Meats  42173
# 6633                         Baby Foods  43408               None
# 6634                         Baby Foods  43539               None
# 6635                         Baby Foods  43546               None
#
# [6636 rows x 4 columns]

# %% [markdown]
# ## Familiarizing yourself with the DF

# %%
info.head()
# Out:
#                           description                   group    id  \
# 0                     Cheese, caraway  Dairy and Egg Products  1008
# 1                     Cheese, cheddar  Dairy and Egg Products  1009
# 2                        Cheese, edam  Dairy and Egg Products  1018
# 3                        Cheese, feta  Dairy and Egg Products  1019
# 4  Cheese, mozzarella, part skim milk  Dairy and Egg Products  1028
#
#   manufacturer
# 0
# 1
# 2
# 3
# 4

# %%
info.tail()
# Out:
#                                             description  \
# 6631                             Bologna, beef, low fat
# 6632  Turkey and pork sausage, fresh, bulk, patty or...
# 6633                              Babyfood, juice, pear
# 6634         Babyfood, dessert, banana yogurt, strained
# 6635              Babyfood, banana no tapioca, strained
#
#                             group     id manufacturer
# 6631  Sausages and Luncheon Meats  42161
# 6632  Sausages and Luncheon Meats  42173
# 6633                   Baby Foods  43408         None
# 6634                   Baby Foods  43539         None
# 6635                   Baby Foods  43546         None

# %%
#look at the columns attribute
print(info.columns)
# Out:
# Index(['description', 'group', 'id', 'manufacturer'], dtype='object')

# %%
#look at the shape attribute
info.shape
# Out:
# (6636, 4)

# %%
#understanding the different types of data for each column
info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6636 entries, 0 to 6635
# Data columns (total 4 columns):
# description     6636 non-null object
# group           6636 non-null object
# id              6636 non-null int64
# manufacturer    5195 non-null object
# dtypes: int64(1), object(3)
# memory usage: 207.5+ KB

# %%
#call on a specific column, can use .head and .tail on series

info['description'].head()   #series object
#seri[0]
# Out:
# 0                       Cheese, caraway
# 1                       Cheese, cheddar
# 2                          Cheese, edam
# 3                          Cheese, feta
# 4    Cheese, mozzarella, part skim milk
# Name: description, dtype: object

# %%
seri[2]
# Out:
# 'Cheese, edam'

# %%
#get descriptive stats by columns
info.describe()
# Out:
#                  id
# count   6636.000000
# mean   15733.055304
# std     8715.095274
# min     1008.000000
# 25%    10170.750000
# 50%    14445.000000
# 75%    19188.250000
# max    93600.000000

# %% [markdown]
# ***Why might .describe() return fewer that all summary stats across our columns?***

# %% [markdown]
# ## Converting objects to a Series

# %%
my_list = [1,2,3,4,5]
my_numpy_array = np.array([1,2,3,4,5])

# %%
my_list_ser = pd.Series(my_list)

# %%
my_list_ser
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
my_numpy_array_ser = pd.Series(my_numpy_array)

# %%
my_numpy_array_ser
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# You can convert a series to a DF for easier viewing. 
# Notice that the column header is automatically assigned.

pd.DataFrame(my_numpy_array_ser)
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %% [markdown]
# ## Converting objects to DataFrames

# %%
# You can use a dict
my_dict = {'my_column_name': ['my', 'column', 'elements', 'go', 'here']}

# %%
my_dict_df = pd.DataFrame(my_dict)

# %%
my_dict_df
# Out:
#   my_column_name
# 0             my
# 1         column
# 2       elements
# 3             go
# 4           here

# %%
# You can also use a list of lists, or an array of arrays
headers = ['my', 'column', 'headers']
list_of_lists = [['col_1_val_1', 'col_2_val_1', 'col_3_val_1'],
               ['col_1_val_2', 'col_2_val_2', 'col_3_val_2'],
               ['col_1_val_3', 'col_2_val_3', 'col_3_val_3']]

# %%
pd.DataFrame(list_of_lists, columns = headers) #if column not defined heads will default to ints
# Out:
#              0            1            2
# 0  col_1_val_1  col_2_val_1  col_3_val_1
# 1  col_1_val_2  col_2_val_2  col_3_val_2
# 2  col_1_val_3  col_2_val_3  col_3_val_3

# %%
#define a ditionary containing employee data
data1 = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'], 
        'Age':[27, 24, 22, 32], 
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'], 
        'Qualification':['Msc', 'MA', 'MCA', 'Phd'],
        'Mobile No': [97, 91, 58, 76]}

# %%
#Convert the dictionary into DataFrame 
df1 = pd.DataFrame(data1)#,index=[0, 1, 2, 3])
df1
# Out:
#      Name  Age    Address Qualification  Mobile No
# 0     Jai   27     Nagpur           Msc         97
# 1  Princi   24     Kanpur            MA         91
# 2  Gaurav   22  Allahabad           MCA         58
# 3    Anuj   32    Kannuaj           Phd         76

# %% [markdown]
# ### Combining Data Frames

# %%
#create a second data frame of employee data to merge the two 
data2 = {'Name':['Gaurav', 'Anuj', 'Dhiraj', 'Hitesh'], 
        'Age':[22, 32, 12, 52], 
        'Address':['Allahabad', 'Kannuaj', 'Allahabad', 'Kannuaj'], 
        'Qualification':['MCA', 'Phd', 'Bcom', 'B.hons'],
        'Salary':[1000, 2000, 3000, 4000]} 

df2 = pd.DataFrame(data2, index=[2, 3, 6, 7]) 
df2.head()
# Out:
#      Name  Age    Address Qualification  Salary
# 2  Gaurav   22  Allahabad           MCA    1000
# 3    Anuj   32    Kannuaj           Phd    2000
# 6  Dhiraj   12  Allahabad          Bcom    3000
# 7  Hitesh   52    Kannuaj        B.hons    4000

# %%
df1
# Out:
#      Name  Age    Address Qualification  Mobile No
# 0     Jai   27     Nagpur           Msc         97
# 1  Princi   24     Kanpur            MA         91
# 2  Gaurav   22  Allahabad           MCA         58
# 3    Anuj   32    Kannuaj           Phd         76

# %% [markdown]
# #### Concatenating Dataframes

# %%
# df1.head()
# df2.head()

# %%
pd.concat([df1, df2], sort=True, axis=0)   #df1 is a list not a df . #axis 0 crunch down, axis=1 smush together horizontally
# Out:
#      Address  Age  Mobile No    Name Qualification  Salary
# 0     Nagpur   27       97.0     Jai           Msc     NaN
# 1     Kanpur   24       91.0  Princi            MA     NaN
# 2  Allahabad   22       58.0  Gaurav           MCA     NaN
# 3    Kannuaj   32       76.0    Anuj           Phd     NaN
# 2  Allahabad   22        NaN  Gaurav           MCA  1000.0
# 3    Kannuaj   32        NaN    Anuj           Phd  2000.0
# 6  Allahabad   12        NaN  Dhiraj          Bcom  3000.0
# 7    Kannuaj   52        NaN  Hitesh        B.hons  4000.0

# %%
pd.concat([df1, df2], sort=True, axis=1)
# Out:
#      Name   Age    Address Qualification  Mobile No    Name   Age    Address  \
# 0     Jai  27.0     Nagpur           Msc       97.0     NaN   NaN        NaN
# 1  Princi  24.0     Kanpur            MA       91.0     NaN   NaN        NaN
# 2  Gaurav  22.0  Allahabad           MCA       58.0  Gaurav  22.0  Allahabad
# 3    Anuj  32.0    Kannuaj           Phd       76.0    Anuj  32.0    Kannuaj
# 6     NaN   NaN        NaN           NaN        NaN  Dhiraj  12.0  Allahabad
# 7     NaN   NaN        NaN           NaN        NaN  Hitesh  52.0    Kannuaj
#
#   Qualification  Salary
# 0           NaN     NaN
# 1           NaN     NaN
# 2           MCA  1000.0
# 3           Phd  2000.0
# 6          Bcom  3000.0
# 7        B.hons  4000.0

# %% [markdown]
# #### Merging Dataframes

# %% [markdown]
# <img src="joinimages.png" alt="drawing" width="550"/>

# %%
pd.merge(df1, df2)
# Out:
#      Name  Age    Address Qualification  Mobile No  Salary
# 0  Gaurav   22  Allahabad           MCA         58    1000
# 1    Anuj   32    Kannuaj           Phd         76    2000

# %%
help(pd.merge)
# Out:
# Help on function merge in module pandas.core.reshape.merge:
#
# merge(left, right, how='inner', on=None, left_on=None, right_on=None, left_index=False, right_index=False, sort=False, suffixes=('_x', '_y'), copy=True, indicator=False, validate=None)
#     Merge DataFrame or named Series objects with a database-style join.
#
#     The join is done on columns or indexes. If joining columns on
#     columns, the DataFrame indexes *will be ignored*. Otherwise if joining indexes
#     on indexes or indexes on a column or columns, the index will be passed on.
#
#     Parameters
#     ----------
#     left : DataFrame
#     right : DataFrame or named Series
#         Object to merge with.
#     how : {'left', 'right', 'outer', 'inner'}, default 'inner'
#         Type of merge to be performed.
#
#         * left: use only keys from left frame, similar to a SQL left outer join;
#           preserve key order.
#         * right: use only keys from right frame, similar to a SQL right outer join;
#           preserve key order.
#         * outer: use union of keys from both frames, similar to a SQL full outer
#           join; sort keys lexicographically.
#         * inner: use intersection of keys from both frames, similar to a SQL inner
#           join; preserve the order of the left keys.
#     on : label or list
#         Column or index level names to join on. These must be found in both
#         DataFrames. If `on` is None and not merging on indexes then this defaults
#         to the intersection of the columns in both DataFrames.
#     left_on : label or list, or array-like
#         Column or index level names to join on in the left DataFrame. Can also
#         be an array or list of arrays of the length of the left DataFrame.
#         These arrays are treated as if they are columns.
#     right_on : label or list, or array-like
#         Column or index level names to join on in the right DataFrame. Can also
#         be an array or list of arrays of the length of the right DataFrame.
#         These arrays are treated as if they are columns.
#     left_index : bool, default False
#         Use the index from the left DataFrame as the join key(s). If it is a
#         MultiIndex, the number of keys in the other DataFrame (either the index
#         or a number of columns) must match the number of levels.
#     right_index : bool, default False
#         Use the index from the right DataFrame as the join key. Same caveats as
#         left_index.
#     sort : bool, default False
#         Sort the join keys lexicographically in the result DataFrame. If False,
#         the order of the join keys depends on the join type (how keyword).
#     suffixes : tuple of (str, str), default ('_x', '_y')
#         Suffix to apply to overlapping column names in the left and right
#         side, respectively. To raise an exception on overlapping columns use
#         (False, False).
#     copy : bool, default True
#         If False, avoid copy if possible.
#     indicator : bool or str, default False
#         If True, adds a column to output DataFrame called "_merge" with
#         information on the source of each row.
#         If string, column with information on source of each row will be added to
#         output DataFrame, and column will be named value of string.
#         Information column is Categorical-type and takes on a value of "left_only"
#         for observations whose merge key only appears in 'left' DataFrame,
#         "right_only" for observations whose merge key only appears in 'right'
#         DataFrame, and "both" if the observation's merge key is found in both.
#
#     validate : str, optional
#         If specified, checks if merge is of specified type.
#
#         * "one_to_one" or "1:1": check if merge keys are unique in both
#           left and right datasets.
#         * "one_to_many" or "1:m": check if merge keys are unique in left
#           dataset.
#         * "many_to_one" or "m:1": check if merge keys are unique in right
#           dataset.
#         * "many_to_many" or "m:m": allowed, but does not result in checks.
#
#         .. versionadded:: 0.21.0
#
#     Returns
#     -------
#     DataFrame
#         A DataFrame of the two merged objects.
#
#     See Also
#     --------
#     merge_ordered : Merge with optional filling/interpolation.
#     merge_asof : Merge on nearest keys.
#     DataFrame.join : Similar method using indices.
#
#     Notes
#     -----
#     Support for specifying index levels as the `on`, `left_on`, and
#     `right_on` parameters was added in version 0.23.0
#     Support for merging named Series objects was added in version 0.24.0
#
#     Examples
#     --------
#
#     >>> df1 = pd.DataFrame({'lkey': ['foo', 'bar', 'baz', 'foo'],
#     ...                     'value': [1, 2, 3, 5]})
#     >>> df2 = pd.DataFrame({'rkey': ['foo', 'bar', 'baz', 'foo'],
#     ...                     'value': [5, 6, 7, 8]})
#     >>> df1
#         lkey value
#     0   foo      1
#     1   bar      2
#     2   baz      3
#     3   foo      5
#     >>> df2
#         rkey value
#     0   foo      5
#     1   bar      6
#     2   baz      7
#     3   foo      8
#
#     Merge df1 and df2 on the lkey and rkey columns. The value columns have
#     the default suffixes, _x and _y, appended.
#
#     >>> df1.merge(df2, left_on='lkey', right_on='rkey')
#       lkey  value_x rkey  value_y
#     0  foo        1  foo        5
#     1  foo        1  foo        8
#     2  foo        5  foo        5
#     3  foo        5  foo        8
#     4  bar        2  bar        6
#     5  baz        3  baz        7
#
#     Merge DataFrames df1 and df2 with specified left and right suffixes
#     appended to any overlapping columns.
#
#     >>> df1.merge(df2, left_on='lkey', right_on='rkey',
#     ...           suffixes=('_left', '_right'))
#       lkey  value_left rkey  value_right
#     0  foo           1  foo            5
#     1  foo           1  foo            8
#     2  foo           5  foo            5
#     3  foo           5  foo            8
#     4  bar           2  bar            6
#     5  baz           3  baz            7
#
#     Merge DataFrames df1 and df2, but raise an exception if the DataFrames have
#     any overlapping columns.
#
#     >>> df1.merge(df2, left_on='lkey', right_on='rkey', suffixes=(False, False))
#     Traceback (most recent call last):
#     ...
#     ValueError: columns overlap but no suffix specified:
#         Index(['value'], dtype='object')

# %% [markdown]
# By calling the merge function on multiple dataframes without any specifications, it tries its best to merge them. It will assess any column that they find to be identical and use those as the merge.

# %%
pd.merge(df1, df2, how='inner')
# Out:
#      Name  Age    Address Qualification  Mobile No  Salary
# 0  Gaurav   22  Allahabad           MCA         58    1000
# 1    Anuj   32    Kannuaj           Phd         76    2000

# %% [markdown]
# If we want to keep all data we should do an outer join

# %%
pd.merge(df1, df2, how='outer')
# Out:
#      Name  Age    Address Qualification  Mobile No  Salary
# 0     Jai   27     Nagpur           Msc       97.0     NaN
# 1  Princi   24     Kanpur            MA       91.0     NaN
# 2  Gaurav   22  Allahabad           MCA       58.0  1000.0
# 3    Anuj   32    Kannuaj           Phd       76.0  2000.0
# 4  Dhiraj   12  Allahabad          Bcom        NaN  3000.0
# 5  Hitesh   52    Kannuaj        B.hons        NaN  4000.0

# %% [markdown]
# If you are only concerned with data from one table, then you can specify that table is what you want to merge on.

# %%
pd.merge(df1, df2, how='right')
# Out:
#      Name  Age    Address Qualification  Mobile No  Salary
# 0  Gaurav   22  Allahabad           MCA       58.0    1000
# 1    Anuj   32    Kannuaj           Phd       76.0    2000
# 2  Dhiraj   12  Allahabad          Bcom        NaN    3000
# 3  Hitesh   52    Kannuaj        B.hons        NaN    4000

# %% [markdown]
# Sometimes you want to be specific in which columns you want the dataframe to merge on

# %%
pd.merge(df1, df2, how='right', on=['Name', 'Age'])
# Out:
#      Name  Age  Address_x Qualification_x  Mobile No  Address_y  \
# 0  Gaurav   22  Allahabad             MCA       58.0  Allahabad
# 1    Anuj   32    Kannuaj             Phd       76.0    Kannuaj
# 2  Dhiraj   12        NaN             NaN        NaN  Allahabad
# 3  Hitesh   52        NaN             NaN        NaN    Kannuaj
#
#   Qualification_y  Salary
# 0             MCA    1000
# 1             Phd    2000
# 2            Bcom    3000
# 3          B.hons    4000

# %% [markdown]
# ## Data transformation
#
# ### Removing duplicates
#
# Duplicate rows may be found in a DataFrame for any number of reasons. Here is an example:

# %%
data = pd.DataFrame({'k1': ['one'] * 3 + ['two'] * 4,
                  'k2': [1, 1, 2, 3, 3, 4, 4]})
data
# Out:
#     k1  k2
# 0  one   1
# 1  one   1
# 2  one   2
# 3  two   3
# 4  two   3
# 5  two   4
# 6  two   4

# %%
# method that returns a boolean Series indicating whether each row 
# is a duplicate or not
data[data.duplicated()]

data.drop_duplicates()
# Out:
#     k1  k2
# 0  one   1
# 2  one   2
# 3  two   3
# 5  two   4

# %% [markdown]
# If I call `data` again why are there still duplicates?

# %%
data
# Out:
#     k1  k2
# 0  one   1
# 1  one   1
# 2  one   2
# 3  two   3
# 4  two   3
# 5  two   4
# 6  two   4

# %%
data.drop_duplicates(inplace=True)
data
# Out:
#     k1  k2  v1
# 0  one   1   0
# 1  one   1   1
# 2  one   2   2
# 3  two   3   3
# 4  two   3   4
# 5  two   4   5
# 6  two   4   6

# %%
data = pd.DataFrame({'k1': ['one'] * 3 + ['two'] * 4,
                  'k2': [1, 1, 2, 3, 3, 4, 4]})

#we are adding another column to help us understand which row was dropped
data['v1'] = range(7)

data
# Out:
#     k1  k2  v1
# 0  one   1   0
# 1  one   1   1
# 2  one   2   2
# 3  two   3   3
# 4  two   3   4
# 5  two   4   5
# 6  two   4   6

# %%
data.drop_duplicates(['k1'])
# Out:
#     k1  k2  v1
# 0  one   1   0
# 3  two   3   3

# %%
data.drop_duplicates(['k1'], keep='last')
# Out:
#     k1  k2  v1
# 2  one   2   2
# 6  two   4   6

# %%
myData = data.drop_duplicates(['k1'], keep='last')

# %% [markdown]
# ### Notice that the index values are no longer incremented evenly by 1
# #### df.reset_index() is your friend. More useful applications of reset_index() coming soon!

# %%
myData.reset_index()
# Out:
#    index   k1  k2  v1
# 0      2  one   2   2
# 1      6  two   4   6

# %% [markdown]
# ## Examining different parts of the data frame

# %%
movies_df = pd.read_csv('IMDB-Movie-Data.csv', index_col='Title')
movies_df.head()
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
#
#                                      Director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# Split                      M. Night Shyamalan
# Sing                     Christophe Lourdelet
# Suicide Squad                      David Ayer
#
#                                                                     Actors  \
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Prometheus               Noomi Rapace, Logan Marshall-Green, Michael Fa...
# Split                    James McAvoy, Anya Taylor-Joy, Haley Lu Richar...
# Sing                     Matthew McConaughey,Reese Witherspoon, Seth Ma...
# Suicide Squad            Will Smith, Jared Leto, Margot Robbie, Viola D...
#
#                          Year  Runtime (Minutes)  Rating   Votes  \
# Title
# Guardians of the Galaxy  2014                121     8.1  757074
# Prometheus               2012                124     7.0  485820
# Split                    2016                117     7.3  157606
# Sing                     2016                108     7.2   60545
# Suicide Squad            2016                123     6.2  393727
#
#                          Revenue (Millions)  Metascore
# Title
# Guardians of the Galaxy              333.13       76.0
# Prometheus                           126.46       65.0
# Split                                138.12       62.0
# Sing                                 270.32       59.0
# Suicide Squad                        325.02       40.0

# %% [markdown]
# #### There are a few different ways to select data from a dataframe

# %%
# Returns a series
movies_df['Rank'].head()
# Out:
# Title
# Guardians of the Galaxy    1
# Prometheus                 2
# Split                      3
# Sing                       4
# Suicide Squad              5
# Name: Rank, dtype: int64

# %%
# Returns a dataframe
movies_df[['Rank']].head()
# Out:
#                          Rank
# Title
# Guardians of the Galaxy     1
# Prometheus                  2
# Split                       3
# Sing                        4
# Suicide Squad               5

# %% [markdown]
# Now we'll look at getting data by rows.
#
# For rows, we have two options:
#
# - .loc - locates by name
# - .iloc- locates by numerical index
#
# Remember that we are still indexed by movie Title, so to use .loc we give it the Title of a movie:

# %%
movies_df.head(3)
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
#
#                                    Director  \
# Title
# Guardians of the Galaxy          James Gunn
# Prometheus                     Ridley Scott
# Split                    M. Night Shyamalan
#
#                                                                     Actors  \
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Prometheus               Noomi Rapace, Logan Marshall-Green, Michael Fa...
# Split                    James McAvoy, Anya Taylor-Joy, Haley Lu Richar...
#
#                          Year  Runtime (Minutes)  Rating   Votes  \
# Title
# Guardians of the Galaxy  2014                121     8.1  757074
# Prometheus               2012                124     7.0  485820
# Split                    2016                117     7.3  157606
#
#                          Revenue (Millions)  Metascore
# Title
# Guardians of the Galaxy              333.13       76.0
# Prometheus                           126.46       65.0
# Split                                138.12       62.0

# %%
# use loc to find the row by name
prom = movies_df.loc["Prometheus"]

prom
# Out:
# Rank                                                                  2
# Genre                                          Adventure,Mystery,Sci-Fi
# Description           Following clues to the origin of mankind, a te...
# Director                                                   Ridley Scott
# Actors                Noomi Rapace, Logan Marshall-Green, Michael Fa...
# Year                                                               2012
# Runtime (Minutes)                                                   124
# Rating                                                                7
# Votes                                                            485820
# Revenue (Millions)                                               126.46
# Metascore                                                            65
# Name: Prometheus, dtype: object

# %%
#use iloc to find the row by numerical index

prom = movies_df.iloc[1,]
prom
# Out:
# Rank                                                                  2
# Genre                                          Adventure,Mystery,Sci-Fi
# Description           Following clues to the origin of mankind, a te...
# Director                                                   Ridley Scott
# Actors                Noomi Rapace, Logan Marshall-Green, Michael Fa...
# Year                                                               2012
# Runtime (Minutes)                                                   124
# Rating                                                                7
# Votes                                                            485820
# Revenue (Millions)                                               126.46
# Metascore                                                            65
# Name: Prometheus, dtype: object

# %% [markdown]
# `loc` and `iloc` can be thought of as similar to Python list slicing. To show this even further, let's select multiple rows.
#
#
# How would you do it with a list? In Python, just slice with brackets like `example_list[1:4]`. It's works the same way in pandas:

# %%
movies_df.loc['Prometheus':'Sing']
# Out:
#             Rank                     Genre  \
# Title
# Prometheus     2  Adventure,Mystery,Sci-Fi
# Split          3           Horror,Thriller
# Sing           4   Animation,Comedy,Family
#
#                                                   Description  \
# Title
# Prometheus  Following clues to the origin of mankind, a te...
# Split       Three girls are kidnapped by a man with a diag...
# Sing        In a city of humanoid animals, a hustling thea...
#
#                         Director  \
# Title
# Prometheus          Ridley Scott
# Split         M. Night Shyamalan
# Sing        Christophe Lourdelet
#
#                                                        Actors  Year  \
# Title
# Prometheus  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012
# Split       James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016
# Sing        Matthew McConaughey,Reese Witherspoon, Seth Ma...  2016
#
#             Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# Title
# Prometheus                124     7.0  485820              126.46       65.0
# Split                     117     7.3  157606              138.12       62.0
# Sing                      108     7.2   60545              270.32       59.0

# %%
mov_df = movies_df.loc['Prometheus':'Sing']
mov_df
# Out:
#             Rank                     Genre  \
# Title
# Prometheus     2  Adventure,Mystery,Sci-Fi
# Split          3           Horror,Thriller
# Sing           4   Animation,Comedy,Family
#
#                                                   Description  \
# Title
# Prometheus  Following clues to the origin of mankind, a te...
# Split       Three girls are kidnapped by a man with a diag...
# Sing        In a city of humanoid animals, a hustling thea...
#
#                         Director  \
# Title
# Prometheus          Ridley Scott
# Split         M. Night Shyamalan
# Sing        Christophe Lourdelet
#
#                                                        Actors  Year  \
# Title
# Prometheus  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012
# Split       James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016
# Sing        Matthew McConaughey,Reese Witherspoon, Seth Ma...  2016
#
#             Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# Title
# Prometheus                124     7.0  485820              126.46       65.0
# Split                     117     7.3  157606              138.12       62.0
# Sing                      108     7.2   60545              270.32       59.0

# %%
# Note that we can use reset_index() to filter upon a numerical index as opposed to a string index
movies_df_reindexed = movies_df.reset_index()
movies_df_reindexed.head()
# Out:
#                      Title  Rank                     Genre  \
# 0  Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# 1               Prometheus     2  Adventure,Mystery,Sci-Fi
# 2                    Split     3           Horror,Thriller
# 3                     Sing     4   Animation,Comedy,Family
# 4            Suicide Squad     5  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012                124
# 2  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016                117
# 3  Matthew McConaughey,Reese Witherspoon, Seth Ma...  2016                108
# 4  Will Smith, Jared Leto, Margot Robbie, Viola D...  2016                123
#
#    Rating   Votes  Revenue (Millions)  Metascore
# 0     8.1  757074              333.13       76.0
# 1     7.0  485820              126.46       65.0
# 2     7.3  157606              138.12       62.0
# 3     7.2   60545              270.32       59.0
# 4     6.2  393727              325.02       40.0

# %%
# Now we can index by integer values
movies_df_reindexed.iloc[1:4]
# Out:
#         Title  Rank                     Genre  \
# 1  Prometheus     2  Adventure,Mystery,Sci-Fi
# 2       Split     3           Horror,Thriller
# 3        Sing     4   Animation,Comedy,Family
#
#                                          Description              Director  \
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
#
#                                               Actors  Year  Runtime (Minutes)  \
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012                124
# 2  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016                117
# 3  Matthew McConaughey,Reese Witherspoon, Seth Ma...  2016                108
#
#    Rating   Votes  Revenue (Millions)  Metascore
# 1     7.0  485820              126.46       65.0
# 2     7.3  157606              138.12       62.0
# 3     7.2   60545              270.32       59.0

# %%
movies_df.iloc[1:4]
# Out:
#             Rank                     Genre  \
# Title
# Prometheus     2  Adventure,Mystery,Sci-Fi
# Split          3           Horror,Thriller
# Sing           4   Animation,Comedy,Family
#
#                                                   Description  \
# Title
# Prometheus  Following clues to the origin of mankind, a te...
# Split       Three girls are kidnapped by a man with a diag...
# Sing        In a city of humanoid animals, a hustling thea...
#
#                         Director  \
# Title
# Prometheus          Ridley Scott
# Split         M. Night Shyamalan
# Sing        Christophe Lourdelet
#
#                                                        Actors  Year  \
# Title
# Prometheus  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012
# Split       James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016
# Sing        Matthew McConaughey,Reese Witherspoon, Seth Ma...  2016
#
#             Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# Title
# Prometheus                124     7.0  485820              126.46       65.0
# Split                     117     7.3  157606              138.12       62.0
# Sing                      108     7.2   60545              270.32       59.0

# %% [markdown]
# ## Deep Copy vs. Shallow Copy

# %%
#make a copy of the dataframe. 
testing = movies_df
testing.head(2)
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
#
#                              Director  \
# Title
# Guardians of the Galaxy    James Gunn
# Prometheus               Ridley Scott
#
#                                                                     Actors  \
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Prometheus               Noomi Rapace, Logan Marshall-Green, Michael Fa...
#
#                          Year  Runtime (Minutes)  Rating   Votes  \
# Title
# Guardians of the Galaxy  2014                121     8.1  757074
# Prometheus               2012                124     7.0  485820
#
#                          Revenue (Millions)  Metascore
# Title
# Guardians of the Galaxy              333.13       76.0
# Prometheus                           126.46       65.0

# %%
#change the values for one column
testing['Director'] = 'SeanAbu'
testing.head(2)
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
#
#                         Director  \
# Title
# Guardians of the Galaxy  SeanAbu
# Prometheus               SeanAbu
#
#                                                                     Actors  \
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Prometheus               Noomi Rapace, Logan Marshall-Green, Michael Fa...
#
#                          Year  Runtime (Minutes)  Rating   Votes  \
# Title
# Guardians of the Galaxy  2014                121     8.1  757074
# Prometheus               2012                124     7.0  485820
#
#                          Revenue (Millions)  Metascore
# Title
# Guardians of the Galaxy              333.13       76.0
# Prometheus                           126.46       65.0

# %% [markdown]
# ***Let's look back at the origianl dataframe***

# %%
movies_df.head(2)
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
#
#                         Director  \
# Title
# Guardians of the Galaxy  SeanAbu
# Prometheus               SeanAbu
#
#                                                                     Actors  \
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Prometheus               Noomi Rapace, Logan Marshall-Green, Michael Fa...
#
#                          Year  Runtime (Minutes)  Rating   Votes  \
# Title
# Guardians of the Galaxy  2014                121     8.1  757074
# Prometheus               2012                124     7.0  485820
#
#                          Revenue (Millions)  Metascore
# Title
# Guardians of the Galaxy              333.13       76.0
# Prometheus                           126.46       65.0

# %% [markdown]
# We created a shallow copy of the dataframe.  What does that mean?

# %%
# Note you can run .copy on a df and a series
s = pd.Series([1, 2], index=["a", "b"])
deep = s.copy(deep=True)
shallow = s.copy(deep=False)

# %% [markdown]
# Shallow copy shares data and index with original.

# %%
s is shallow
# Out:
# False

# %%
s.values is shallow.values and s.index is shallow.index
# Out:
# True

# %% [markdown]
# Deep copy has own copy of data and index.

# %%
s is deep
# Out:
# False

# %%
s.values is deep.values or s.index is deep.index
# Out:
# False

# %% [markdown]
# Updates to the data shared by shallow copy and original is reflected in both; deep copy remains unchanged.

# %%
s[0] = 3
shallow[1] = 4

# %%
s
# Out:
# a    3
# b    4
# dtype: int64

# %%
shallow
# Out:
# a    3
# b    4
# dtype: int64

# %%
deep
# Out:
# a    1
# b    2
# dtype: int64

# %% [markdown]
# ## Conditional selections
#
#
# For example, what if we want to filter our movies DataFrame to show only films directed by Ridley Scott or films with a rating greater than or equal to 8.0?
#
# To do that, we take a column from the DataFrame and apply a Boolean condition to it. Here's an example of a Boolean condition:

# %%
movies_df = pd.read_csv('IMDB-Movie-Data.csv', index_col='Title')

# %% [markdown]
# ### In Pandas

# %%
condition = (movies_df['Director'] == "Ridley Scott")

condition
# Out:
# Title
# Guardians of the Galaxy                    False
# Prometheus                                  True
# Split                                      False
# Sing                                       False
# Suicide Squad                              False
# The Great Wall                             False
# La La Land                                 False
# Mindhorn                                   False
# The Lost City of Z                         False
# Passengers                                 False
# Fantastic Beasts and Where to Find Them    False
# Hidden Figures                             False
# Rogue One                                  False
# Moana                                      False
# Colossal                                   False
# The Secret Life of Pets                    False
# Hacksaw Ridge                              False
# Jason Bourne                               False
# Lion                                       False
# Arrival                                    False
# Gold                                       False
# Manchester by the Sea                      False
# Hounds of Love                             False
# Trolls                                     False
# Independence Day: Resurgence               False
# Paris pieds nus                            False
# Bahubali: The Beginning                    False
# Dead Awake                                 False
# Bad Moms                                   False
# Assassin's Creed                           False
#                                            ...
# Texas Chainsaw 3D                          False
# Disturbia                                  False
# Rock of Ages                               False
# Scream 4                                   False
# Queen of Katwe                             False
# My Big Fat Greek Wedding 2                 False
# Dark Places                                False
# Amateur Night                              False
# It's Only the End of the World             False
# The Skin I Live In                         False
# Miracles from Heaven                       False
# Annie                                      False
# Across the Universe                        False
# Let's Be Cops                              False
# Max                                        False
# Your Highness                              False
# Final Destination 5                        False
# Endless Love                               False
# Martyrs                                    False
# Selma                                      False
# Underworld: Rise of the Lycans             False
# Taare Zameen Par                           False
# Take Me Home Tonight                       False
# Resident Evil: Afterlife                   False
# Project X                                  False
# Secret in Their Eyes                       False
# Hostel: Part II                            False
# Step Up 2: The Streets                     False
# Search Party                               False
# Nine Lives                                 False
# Name: Director, Length: 1000, dtype: bool

# %% [markdown]
# We want to filter out all movies not directed by Ridley Scott, in other words, we don’t want the False films. To return the rows where that condition is True we have to pass this operation into the DataFrame:

# %%
movies_df[condition]
# Out:
#                         Rank                     Genre  \
# Title
# Prometheus                 2  Adventure,Mystery,Sci-Fi
# The Martian              103    Adventure,Drama,Sci-Fi
# Robin Hood               388    Action,Adventure,Drama
# American Gangster        471     Biography,Crime,Drama
# Exodus: Gods and Kings   517    Action,Adventure,Drama
# The Counselor            522      Crime,Drama,Thriller
# A Good Year              531      Comedy,Drama,Romance
# Body of Lies             738      Action,Drama,Romance
#
#                                                               Description  \
# Title
# Prometheus              Following clues to the origin of mankind, a te...
# The Martian             An astronaut becomes stranded on Mars after hi...
# Robin Hood              In 12th century England, Robin and his band of...
# American Gangster       In 1970s America, a detective works to bring d...
# Exodus: Gods and Kings  The defiant leader Moses rises up against the ...
# The Counselor           A lawyer finds himself in over his head when h...
# A Good Year             A British investment broker inherits his uncle...
# Body of Lies            A CIA agent on the ground in Jordan hunts down...
#
#                             Director  \
# Title
# Prometheus              Ridley Scott
# The Martian             Ridley Scott
# Robin Hood              Ridley Scott
# American Gangster       Ridley Scott
# Exodus: Gods and Kings  Ridley Scott
# The Counselor           Ridley Scott
# A Good Year             Ridley Scott
# Body of Lies            Ridley Scott
#
#                                                                    Actors  \
# Title
# Prometheus              Noomi Rapace, Logan Marshall-Green, Michael Fa...
# The Martian             Matt Damon, Jessica Chastain, Kristen Wiig, Ka...
# Robin Hood              Russell Crowe, Cate Blanchett, Matthew Macfady...
# American Gangster       Denzel Washington, Russell Crowe, Chiwetel Eji...
# Exodus: Gods and Kings  Christian Bale, Joel Edgerton, Ben Kingsley, S...
# The Counselor           Michael Fassbender, Penélope Cruz, Cameron Dia...
# A Good Year             Russell Crowe, Abbie Cornish, Albert Finney, M...
# Body of Lies            Leonardo DiCaprio, Russell Crowe, Mark Strong,...
#
#                         Year  Runtime (Minutes)  Rating   Votes  \
# Title
# Prometheus              2012                124     7.0  485820
# The Martian             2015                144     8.0  556097
# Robin Hood              2010                140     6.7  221117
# American Gangster       2007                157     7.8  337835
# Exodus: Gods and Kings  2014                150     6.0  137299
# The Counselor           2013                117     5.3   84927
# A Good Year             2006                117     6.9   74674
# Body of Lies            2008                128     7.1  182305
#
#                         Revenue (Millions)  Metascore
# Title
# Prometheus                          126.46       65.0
# The Martian                         228.43       80.0
# Robin Hood                          105.22       53.0
# American Gangster                   130.13       76.0
# Exodus: Gods and Kings               65.01       52.0
# The Counselor                        16.97       48.0
# A Good Year                           7.46       47.0
# Body of Lies                         39.38       57.0

# %%
movies_df[movies_df['Director'] == "Ridley Scott"]
# Out:
#                         Rank                     Genre  \
# Title
# Prometheus                 2  Adventure,Mystery,Sci-Fi
# The Martian              103    Adventure,Drama,Sci-Fi
# Robin Hood               388    Action,Adventure,Drama
# American Gangster        471     Biography,Crime,Drama
# Exodus: Gods and Kings   517    Action,Adventure,Drama
# The Counselor            522      Crime,Drama,Thriller
# A Good Year              531      Comedy,Drama,Romance
# Body of Lies             738      Action,Drama,Romance
#
#                                                               Description  \
# Title
# Prometheus              Following clues to the origin of mankind, a te...
# The Martian             An astronaut becomes stranded on Mars after hi...
# Robin Hood              In 12th century England, Robin and his band of...
# American Gangster       In 1970s America, a detective works to bring d...
# Exodus: Gods and Kings  The defiant leader Moses rises up against the ...
# The Counselor           A lawyer finds himself in over his head when h...
# A Good Year             A British investment broker inherits his uncle...
# Body of Lies            A CIA agent on the ground in Jordan hunts down...
#
#                             Director  \
# Title
# Prometheus              Ridley Scott
# The Martian             Ridley Scott
# Robin Hood              Ridley Scott
# American Gangster       Ridley Scott
# Exodus: Gods and Kings  Ridley Scott
# The Counselor           Ridley Scott
# A Good Year             Ridley Scott
# Body of Lies            Ridley Scott
#
#                                                                    Actors  \
# Title
# Prometheus              Noomi Rapace, Logan Marshall-Green, Michael Fa...
# The Martian             Matt Damon, Jessica Chastain, Kristen Wiig, Ka...
# Robin Hood              Russell Crowe, Cate Blanchett, Matthew Macfady...
# American Gangster       Denzel Washington, Russell Crowe, Chiwetel Eji...
# Exodus: Gods and Kings  Christian Bale, Joel Edgerton, Ben Kingsley, S...
# The Counselor           Michael Fassbender, Penélope Cruz, Cameron Dia...
# A Good Year             Russell Crowe, Abbie Cornish, Albert Finney, M...
# Body of Lies            Leonardo DiCaprio, Russell Crowe, Mark Strong,...
#
#                         Year  Runtime (Minutes)  Rating   Votes  \
# Title
# Prometheus              2012                124     7.0  485820
# The Martian             2015                144     8.0  556097
# Robin Hood              2010                140     6.7  221117
# American Gangster       2007                157     7.8  337835
# Exodus: Gods and Kings  2014                150     6.0  137299
# The Counselor           2013                117     5.3   84927
# A Good Year             2006                117     6.9   74674
# Body of Lies            2008                128     7.1  182305
#
#                         Revenue (Millions)  Metascore
# Title
# Prometheus                          126.46       65.0
# The Martian                         228.43       80.0
# Robin Hood                          105.22       53.0
# American Gangster                   130.13       76.0
# Exodus: Gods and Kings               65.01       52.0
# The Counselor                        16.97       48.0
# A Good Year                           7.46       47.0
# Body of Lies                         39.38       57.0

# %% [markdown]
# **Find how many movies were directed by Christopher Nolan.**

# %%
#put your code here

movies_df[movies_df['Director'] == "Christopher Nolan"]
# Out:
#                        Rank                    Genre  \
# Title
# Interstellar             37   Adventure,Drama,Sci-Fi
# The Dark Knight          55       Action,Crime,Drama
# The Prestige             65     Drama,Mystery,Sci-Fi
# Inception                81  Action,Adventure,Sci-Fi
# The Dark Knight Rises   125          Action,Thriller
#
#                                                              Description  \
# Title
# Interstellar           A team of explorers travel through a wormhole ...
# The Dark Knight        When the menace known as the Joker wreaks havo...
# The Prestige           Two stage magicians engage in competitive one-...
# Inception              A thief, who steals corporate secrets through ...
# The Dark Knight Rises  Eight years after the Joker's reign of anarchy...
#
#                                 Director  \
# Title
# Interstellar           Christopher Nolan
# The Dark Knight        Christopher Nolan
# The Prestige           Christopher Nolan
# Inception              Christopher Nolan
# The Dark Knight Rises  Christopher Nolan
#
#                                                                   Actors  \
# Title
# Interstellar           Matthew McConaughey, Anne Hathaway, Jessica Ch...
# The Dark Knight        Christian Bale, Heath Ledger, Aaron Eckhart,Mi...
# The Prestige           Christian Bale, Hugh Jackman, Scarlett Johanss...
# Inception              Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...
# The Dark Knight Rises  Christian Bale, Tom Hardy, Anne Hathaway,Gary ...
#
#                        Year  Runtime (Minutes)  Rating    Votes  \
# Title
# Interstellar           2014                169     8.6  1047747
# The Dark Knight        2008                152     9.0  1791916
# The Prestige           2006                130     8.5   913152
# Inception              2010                148     8.8  1583625
# The Dark Knight Rises  2012                164     8.5  1222645
#
#                        Revenue (Millions)  Metascore
# Title
# Interstellar                       187.99       74.0
# The Dark Knight                    533.32       82.0
# The Prestige                        53.08       66.0
# Inception                          292.57       74.0
# The Dark Knight Rises              448.13       78.0

# %% [markdown]
# Let's look at conditional selections using numerical values by filtering the DataFrame by ratings:

# %%
movies_df[movies_df['Rating'] >= 8.8]
# Out:
#                  Rank                    Genre  \
# Title
# The Dark Knight    55       Action,Crime,Drama
# Inception          81  Action,Adventure,Sci-Fi
# Dangal            118   Action,Biography,Drama
#
#                                                        Description  \
# Title
# The Dark Knight  When the menace known as the Joker wreaks havo...
# Inception        A thief, who steals corporate secrets through ...
# Dangal           Former wrestler Mahavir Singh Phogat and his t...
#
#                           Director  \
# Title
# The Dark Knight  Christopher Nolan
# Inception        Christopher Nolan
# Dangal               Nitesh Tiwari
#
#                                                             Actors  Year  \
# Title
# The Dark Knight  Christian Bale, Heath Ledger, Aaron Eckhart,Mi...  2008
# Inception        Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...  2010
# Dangal           Aamir Khan, Sakshi Tanwar, Fatima Sana Shaikh,...  2016
#
#                  Runtime (Minutes)  Rating    Votes  Revenue (Millions)  \
# Title
# The Dark Knight                152     9.0  1791916              533.32
# Inception                      148     8.8  1583625              292.57
# Dangal                         161     8.8    48969               11.15
#
#                  Metascore
# Title
# The Dark Knight       82.0
# Inception             74.0
# Dangal                 NaN

# %% [markdown]
# We can make some richer conditionals by using logical operators:
# - `|`    for "or"
# - `&`    for "and"
#
#
# Let's filter the the DataFrame to show only movies by Christopher Nolan OR Ridley Scott:

# %%
movies_df[(movies_df['Director'] == 'Christopher Nolan') | (movies_df['Director'] == 'Ridley Scott')]
# Out:
#                         Rank                     Genre  \
# Title
# Prometheus                 2  Adventure,Mystery,Sci-Fi
# Interstellar              37    Adventure,Drama,Sci-Fi
# The Dark Knight           55        Action,Crime,Drama
# The Prestige              65      Drama,Mystery,Sci-Fi
# Inception                 81   Action,Adventure,Sci-Fi
# The Martian              103    Adventure,Drama,Sci-Fi
# The Dark Knight Rises    125           Action,Thriller
# Robin Hood               388    Action,Adventure,Drama
# American Gangster        471     Biography,Crime,Drama
# Exodus: Gods and Kings   517    Action,Adventure,Drama
# The Counselor            522      Crime,Drama,Thriller
# A Good Year              531      Comedy,Drama,Romance
# Body of Lies             738      Action,Drama,Romance
#
#                                                               Description  \
# Title
# Prometheus              Following clues to the origin of mankind, a te...
# Interstellar            A team of explorers travel through a wormhole ...
# The Dark Knight         When the menace known as the Joker wreaks havo...
# The Prestige            Two stage magicians engage in competitive one-...
# Inception               A thief, who steals corporate secrets through ...
# The Martian             An astronaut becomes stranded on Mars after hi...
# The Dark Knight Rises   Eight years after the Joker's reign of anarchy...
# Robin Hood              In 12th century England, Robin and his band of...
# American Gangster       In 1970s America, a detective works to bring d...
# Exodus: Gods and Kings  The defiant leader Moses rises up against the ...
# The Counselor           A lawyer finds himself in over his head when h...
# A Good Year             A British investment broker inherits his uncle...
# Body of Lies            A CIA agent on the ground in Jordan hunts down...
#
#                                  Director  \
# Title
# Prometheus                   Ridley Scott
# Interstellar            Christopher Nolan
# The Dark Knight         Christopher Nolan
# The Prestige            Christopher Nolan
# Inception               Christopher Nolan
# The Martian                  Ridley Scott
# The Dark Knight Rises   Christopher Nolan
# Robin Hood                   Ridley Scott
# American Gangster            Ridley Scott
# Exodus: Gods and Kings       Ridley Scott
# The Counselor                Ridley Scott
# A Good Year                  Ridley Scott
# Body of Lies                 Ridley Scott
#
#                                                                    Actors  \
# Title
# Prometheus              Noomi Rapace, Logan Marshall-Green, Michael Fa...
# Interstellar            Matthew McConaughey, Anne Hathaway, Jessica Ch...
# The Dark Knight         Christian Bale, Heath Ledger, Aaron Eckhart,Mi...
# The Prestige            Christian Bale, Hugh Jackman, Scarlett Johanss...
# Inception               Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...
# The Martian             Matt Damon, Jessica Chastain, Kristen Wiig, Ka...
# The Dark Knight Rises   Christian Bale, Tom Hardy, Anne Hathaway,Gary ...
# Robin Hood              Russell Crowe, Cate Blanchett, Matthew Macfady...
# American Gangster       Denzel Washington, Russell Crowe, Chiwetel Eji...
# Exodus: Gods and Kings  Christian Bale, Joel Edgerton, Ben Kingsley, S...
# The Counselor           Michael Fassbender, Penélope Cruz, Cameron Dia...
# A Good Year             Russell Crowe, Abbie Cornish, Albert Finney, M...
# Body of Lies            Leonardo DiCaprio, Russell Crowe, Mark Strong,...
#
#                         Year  Runtime (Minutes)  Rating    Votes  \
# Title
# Prometheus              2012                124     7.0   485820
# Interstellar            2014                169     8.6  1047747
# The Dark Knight         2008                152     9.0  1791916
# The Prestige            2006                130     8.5   913152
# Inception               2010                148     8.8  1583625
# The Martian             2015                144     8.0   556097
# The Dark Knight Rises   2012                164     8.5  1222645
# Robin Hood              2010                140     6.7   221117
# American Gangster       2007                157     7.8   337835
# Exodus: Gods and Kings  2014                150     6.0   137299
# The Counselor           2013                117     5.3    84927
# A Good Year             2006                117     6.9    74674
# Body of Lies            2008                128     7.1   182305
#
#                         Revenue (Millions)  Metascore
# Title
# Prometheus                          126.46       65.0
# Interstellar                        187.99       74.0
# The Dark Knight                     533.32       82.0
# The Prestige                         53.08       66.0
# Inception                           292.57       74.0
# The Martian                         228.43       80.0
# The Dark Knight Rises               448.13       78.0
# Robin Hood                          105.22       53.0
# American Gangster                   130.13       76.0
# Exodus: Gods and Kings               65.01       52.0
# The Counselor                        16.97       48.0
# A Good Year                           7.46       47.0
# Body of Lies                         39.38       57.0

# %% [markdown]
# ** Find all of the movies by a Christopher Nolan that have a score of 8.7 or better**

# %%
# your code here

movies_df[(movies_df['Director'] == 'Christopher Nolan') & (movies_df['Metascore'] >= 8.7)]
# Out:
#                        Rank                    Genre  \
# Title
# Interstellar             37   Adventure,Drama,Sci-Fi
# The Dark Knight          55       Action,Crime,Drama
# The Prestige             65     Drama,Mystery,Sci-Fi
# Inception                81  Action,Adventure,Sci-Fi
# The Dark Knight Rises   125          Action,Thriller
#
#                                                              Description  \
# Title
# Interstellar           A team of explorers travel through a wormhole ...
# The Dark Knight        When the menace known as the Joker wreaks havo...
# The Prestige           Two stage magicians engage in competitive one-...
# Inception              A thief, who steals corporate secrets through ...
# The Dark Knight Rises  Eight years after the Joker's reign of anarchy...
#
#                                 Director  \
# Title
# Interstellar           Christopher Nolan
# The Dark Knight        Christopher Nolan
# The Prestige           Christopher Nolan
# Inception              Christopher Nolan
# The Dark Knight Rises  Christopher Nolan
#
#                                                                   Actors  \
# Title
# Interstellar           Matthew McConaughey, Anne Hathaway, Jessica Ch...
# The Dark Knight        Christian Bale, Heath Ledger, Aaron Eckhart,Mi...
# The Prestige           Christian Bale, Hugh Jackman, Scarlett Johanss...
# Inception              Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...
# The Dark Knight Rises  Christian Bale, Tom Hardy, Anne Hathaway,Gary ...
#
#                        Year  Runtime (Minutes)  Rating    Votes  \
# Title
# Interstellar           2014                169     8.6  1047747
# The Dark Knight        2008                152     9.0  1791916
# The Prestige           2006                130     8.5   913152
# Inception              2010                148     8.8  1583625
# The Dark Knight Rises  2012                164     8.5  1222645
#
#                        Revenue (Millions)  Metascore
# Title
# Interstellar                       187.99       74.0
# The Dark Knight                    533.32       82.0
# The Prestige                        53.08       66.0
# Inception                          292.57       74.0
# The Dark Knight Rises              448.13       78.0

# %% [markdown]
# Using the `isin()` method we could make this more concise though:

# %%
movies_df[movies_df['Director'].isin(['Christopher Nolan', 'Ridley Scott'])]
# Out:
#                         Rank                     Genre  \
# Title
# Prometheus                 2  Adventure,Mystery,Sci-Fi
# Interstellar              37    Adventure,Drama,Sci-Fi
# The Dark Knight           55        Action,Crime,Drama
# The Prestige              65      Drama,Mystery,Sci-Fi
# Inception                 81   Action,Adventure,Sci-Fi
# The Martian              103    Adventure,Drama,Sci-Fi
# The Dark Knight Rises    125           Action,Thriller
# Robin Hood               388    Action,Adventure,Drama
# American Gangster        471     Biography,Crime,Drama
# Exodus: Gods and Kings   517    Action,Adventure,Drama
# The Counselor            522      Crime,Drama,Thriller
# A Good Year              531      Comedy,Drama,Romance
# Body of Lies             738      Action,Drama,Romance
#
#                                                               Description  \
# Title
# Prometheus              Following clues to the origin of mankind, a te...
# Interstellar            A team of explorers travel through a wormhole ...
# The Dark Knight         When the menace known as the Joker wreaks havo...
# The Prestige            Two stage magicians engage in competitive one-...
# Inception               A thief, who steals corporate secrets through ...
# The Martian             An astronaut becomes stranded on Mars after hi...
# The Dark Knight Rises   Eight years after the Joker's reign of anarchy...
# Robin Hood              In 12th century England, Robin and his band of...
# American Gangster       In 1970s America, a detective works to bring d...
# Exodus: Gods and Kings  The defiant leader Moses rises up against the ...
# The Counselor           A lawyer finds himself in over his head when h...
# A Good Year             A British investment broker inherits his uncle...
# Body of Lies            A CIA agent on the ground in Jordan hunts down...
#
#                                  Director  \
# Title
# Prometheus                   Ridley Scott
# Interstellar            Christopher Nolan
# The Dark Knight         Christopher Nolan
# The Prestige            Christopher Nolan
# Inception               Christopher Nolan
# The Martian                  Ridley Scott
# The Dark Knight Rises   Christopher Nolan
# Robin Hood                   Ridley Scott
# American Gangster            Ridley Scott
# Exodus: Gods and Kings       Ridley Scott
# The Counselor                Ridley Scott
# A Good Year                  Ridley Scott
# Body of Lies                 Ridley Scott
#
#                                                                    Actors  \
# Title
# Prometheus              Noomi Rapace, Logan Marshall-Green, Michael Fa...
# Interstellar            Matthew McConaughey, Anne Hathaway, Jessica Ch...
# The Dark Knight         Christian Bale, Heath Ledger, Aaron Eckhart,Mi...
# The Prestige            Christian Bale, Hugh Jackman, Scarlett Johanss...
# Inception               Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...
# The Martian             Matt Damon, Jessica Chastain, Kristen Wiig, Ka...
# The Dark Knight Rises   Christian Bale, Tom Hardy, Anne Hathaway,Gary ...
# Robin Hood              Russell Crowe, Cate Blanchett, Matthew Macfady...
# American Gangster       Denzel Washington, Russell Crowe, Chiwetel Eji...
# Exodus: Gods and Kings  Christian Bale, Joel Edgerton, Ben Kingsley, S...
# The Counselor           Michael Fassbender, Penélope Cruz, Cameron Dia...
# A Good Year             Russell Crowe, Abbie Cornish, Albert Finney, M...
# Body of Lies            Leonardo DiCaprio, Russell Crowe, Mark Strong,...
#
#                         Year  Runtime (Minutes)  Rating    Votes  \
# Title
# Prometheus              2012                124     7.0   485820
# Interstellar            2014                169     8.6  1047747
# The Dark Knight         2008                152     9.0  1791916
# The Prestige            2006                130     8.5   913152
# Inception               2010                148     8.8  1583625
# The Martian             2015                144     8.0   556097
# The Dark Knight Rises   2012                164     8.5  1222645
# Robin Hood              2010                140     6.7   221117
# American Gangster       2007                157     7.8   337835
# Exodus: Gods and Kings  2014                150     6.0   137299
# The Counselor           2013                117     5.3    84927
# A Good Year             2006                117     6.9    74674
# Body of Lies            2008                128     7.1   182305
#
#                         Revenue (Millions)  Metascore
# Title
# Prometheus                          126.46       65.0
# Interstellar                        187.99       74.0
# The Dark Knight                     533.32       82.0
# The Prestige                         53.08       66.0
# Inception                           292.57       74.0
# The Martian                         228.43       80.0
# The Dark Knight Rises               448.13       78.0
# Robin Hood                          105.22       53.0
# American Gangster                   130.13       76.0
# Exodus: Gods and Kings               65.01       52.0
# The Counselor                        16.97       48.0
# A Good Year                           7.46       47.0
# Body of Lies                         39.38       57.0

# %% [markdown]
# Using `~` flips your booleans and allows you to find the inverse of your query.

# %%
movies_df[~movies_df['Director'].isin(['Christopher Nolan', 'Ridley Scott'])].head()
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# The Great Wall              6  Action,Adventure,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
# The Great Wall           European mercenaries searching for black powde...
#
#                                      Director  \
# Title
# Guardians of the Galaxy            James Gunn
# Split                      M. Night Shyamalan
# Sing                     Christophe Lourdelet
# Suicide Squad                      David Ayer
# The Great Wall                    Yimou Zhang
#
#                                                                     Actors  \
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Split                    James McAvoy, Anya Taylor-Joy, Haley Lu Richar...
# Sing                     Matthew McConaughey,Reese Witherspoon, Seth Ma...
# Suicide Squad            Will Smith, Jared Leto, Margot Robbie, Viola D...
# The Great Wall               Matt Damon, Tian Jing, Willem Dafoe, Andy Lau
#
#                          Year  Runtime (Minutes)  Rating   Votes  \
# Title
# Guardians of the Galaxy  2014                121     8.1  757074
# Split                    2016                117     7.3  157606
# Sing                     2016                108     7.2   60545
# Suicide Squad            2016                123     6.2  393727
# The Great Wall           2016                103     6.1   56036
#
#                          Revenue (Millions)  Metascore
# Title
# Guardians of the Galaxy              333.13       76.0
# Split                                138.12       62.0
# Sing                                 270.32       59.0
# Suicide Squad                        325.02       40.0
# The Great Wall                        45.13       42.0

# %% [markdown]
# There is also a [Dataframe.query()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.query.html) method that allows you to perform these conditional selections.

# %%
# movies_df.query('Rating >= 8')

# %%
# movies_df.query('Director == "Christopher Nolan" | Director == "Ridley Scott"')

# %% [markdown]
# ## Applied Question:
#
# Which group of movies has the higher average revenue those with a rating of above 8, or those with at least 300,000 reviews?

# %%
# Subset the dataframe to find movies with a rating above 8.

# %%
# Find the average revenue of that group.

# %%
# Subset the dataframe to find movies with more than 300,000 votes.

# %%
# find the average of that group

# %%
# compare the two groups' mean revenue
